# %%
import pandas as pd # standard python data library
import geopandas as gp # the geo-version of pandas
import numpy as np 
import os
import fiona
from statistics import mean, median
from pandas import read_csv
gp.io.file.fiona.drvsupport.supported_drivers['KML'] = 'rw' #To load KML files
import string
import xml.etree.ElementTree as et

# %% [markdown]
# # Georgia

# %% [markdown]
# ## Election Results Documentation:

# %% [markdown]
# Election results from the Georgia Secretary of State Elections Division (https://sos.ga.gov/index.php/Elections/current_and_past_elections_results). Presidential recount results from the Georgia Secretary of State Elections Division via Reuters.

# %% [markdown]
# ## Shapefile Source Documentation:

# %% [markdown]
# Precinct shapefile primarily from the Georgia General Assembly Reapportionment Office (http://www.legis.ga.gov/Joint/reapportionment/en-US/default.aspx).
# Cobb, DeKalb, and Gwinnett counties instead use shapefiles from the U.S. Census Bureau's 2020 Redistricting Data Program.
# Forsyth and Fulton use shapefiles sourced from the respective counties.

# %% [markdown]
# ## Shapefile Modifications Documentation:

# %% [markdown]
# Three of the four VTDs in Chattahoochee County are comprised of Fort Benning. However, the county only reports one polling location for all voters, including residents of Fort Benning that vote within the county. The four Chattahoochee County VTDs have therefore been merged in the shapefile.
#
# The following additional modifications reflect changes made prior to the 2020 general election.
#
# Barrow: Merge 2/15, 3/12, 4/14, 5/7, 6/10/13, 8/9, 11/16; Adjust new 2/13 boundary
# Bartow: Split Cassville/Hamilton Crossing
# Candler: Merge Candler/Metter as Jack Strickland Comm Center
# Chatham: Split 7-7/8-16, 7-12/7-16; Realign 7-06C/7-07C
# Chatooga: Split Cloudland/Teloga along ridgeline that marks boundary between them with the USGS Topographic Contour shapefile
# Clayton: Split Ellenswood 1/2, Jonesboro 1/17/19, Lovejoy 3/6/7, Morrow 3/11, 5/10, Oak 3/5
# Cobb: Split Bells Ferry 3/4, Dobbins 1/2, Marietta 3A/3B, Smyrna 3A/3B
# Columbia: Split Bessie Thomas/2nd Mt Moriah, Harlem Branch/Harlem Senior Ctr; Merge Blanchard Park/MTZ Col FD;  Align multiple precincts with county maps
# Coweta: Merge Arts Centre/Jefferson Parkway as Newnan Centre
# Fulton: Merge CP07A/CP07D, CH01/CH04B, SS29A/SS29B, UC031/UC035
# DeKalb: Split Clarkston/Clarkston Comm Ctr; Realign Decatur/Oakhurst; Align precincts with Atlanta, Brookhaven, Decatur, Tucker city limits
# Gwinnett: Adjust Baycreek F/G, Berkshire J/M, Cates D/F, Garners C/B, Lawrenceville G/N, Pinckneyville S/T, Rockbridge A/G
# Lowndes: Split Northgate Assembly/Trinity, Jaycee/Mt Calvary/Northside/VSU
# Oconee: Merge Annex/City Hall; Align City Hall with Watkinsville city limits
# Paulding: Reorganize 12 precincts into 19 precincts as redrawn in 2019
# Randolph: Merge Carnegie/Cuthbert-Courthouse, 4th District/Fountain Bridge/Shellman
# Troup: Split Mountville between Gardner Newman/Hogansville/Rosemont; Align multiple precincts with county maps
# Towns: Merge Macedonia/Tate City
# Wilkes: Align 1/2A boundary with the voter file
# Note that the leading zeros in the Paulding County precinct IDs are included in some election reports and omitted in others. The shapefile includes the leading zeros consistent with the voter file.

# %% [markdown]
# ## Candidate List

# %% [markdown]
# G20PRERTRU - Donald J. Trump (Republican Party)
# G20PREDBID - Joseph R. Biden (Democratic Party)
# G20PRELJOR - Jo Jorgensen (Libertarian Party)
#
# C20PRERTRU - Donald J. Trump (Republican Party)
# C20PREDBID - Joseph R. Biden (Democratic Party)
# C20PRELJOR - Jo Jorgensen (Libertarian Party)
#
# G20USSRPER - David A. Perdue (Republican Party)
# G20USSDOSS - Jon Ossoff (Democratic Party)
# G20USSLHAZ - Shane Hazel (Libertarian Party)
#
# S20USSRLOE - Kelly Loeffler (Republican Party)
# S20USSRCOL - Doug Collins (Republican Party)
# S20USSRGRA - Derrick E. Grayson (Republican Party)
# S20USSRJAC - Annette Davis Jackson (Republican Party)
# S20USSRTAY - Kandiss Taylor (Republican Party)
# S20USSRJOH - A. Wayne Johnson (Republican Party)
# S20USSDWAR - Raphael Warnock (Democratic Party)
# S20USSDJAC - Deborah Jackson (Democratic Party)
# S20USSDLIE - Matt Lieberman (Democratic Party)
# S20USSDJOH - Tamara Johnson-Shealey (Democratic Party)
# S20USSDJAM - Jamesia James (Democratic Party)
# S20USSDSLA - Joy Felicia Slade (Democratic Party)
# S20USSDWIN - Richard Dien Winfield (Democratic Party)
# S20USSDTAR - Ed Tarver (Democratic Party)
# S20USSLSLO - Brian Slowinski (Libertarian Party)
# S20USSGFOR - John Fortuin (Green Party)
# S20USSIBUC - Allen Buckley (Independent)
# S20USSIBAR - Al Bartell (Independent)
# S20USSISTO - Valencia Stovall (Independent)
# S20USSIGRE - Michael Todd Greene (Independent)
#
# G20PSCRSHA - Jason Shaw (Republican Party)
# G20PSCDBRY - Robert G. Bryant (Democratic Party)
# G20PSCLMEL - Elizabeth Melton (Libertarian Party)
#
# G20PSCRMCD - Lauren Bubba McDonald, Jr. (Republican Party)
# G20PSCDBLA - Daniel Blackman (Democratic Party)
# G20PSCLWIL - Nathan Wilson (Libertarian Party)
#
# R21USSRPER - David A. Perdue (Republican Party)
# R21USSDOSS - Jon Ossoff (Democratic Party)
#
# R21USSRLOE - Kelly Loeffler (Republican Party)
# R21USSDWAR - Raphael Warnock (Democratic Party)
#
# R21PSCRMCD - Lauren Bubba McDonald, Jr. (Republican Party)
# P21PSCDBLA - Daniel Blackman (Democratic Party)

# %% [markdown]
# ### Load the VEST file

# %%
vest_ga_20 = gp.read_file("./raw-from-source/VEST/ga_2020/ga_2020.shp")
print(vest_ga_20.shape)
# Out:
# (2679, 50)

# %%
# Take a look
vest_ga_20.head(1)

#Create a list of the race columns
data_columns = [i for i in vest_ga_20.columns if (("20" in i) | ("21" in i))]
print(data_columns)
# Out:
# ['G20PRERTRU', 'G20PREDBID', 'G20PRELJOR', 'C20PRERTRU', 'C20PREDBID', 'C20PRELJOR', 'G20USSRPER', 'G20USSDOSS', 'G20USSLHAZ', 'S20USSRLOE', 'S20USSRCOL', 'S20USSRGRA', 'S20USSRJAC', 'S20USSRTAY', 'S20USSRJOH', 'S20USSDWAR', 'S20USSDJAC', 'S20USSDLIE', 'S20USSDJOH', 'S20USSDJAM', 'S20USSDSLA', 'S20USSDWIN', 'S20USSDTAR', 'S20USSLSLO', 'S20USSGFOR', 'S20USSIBUC', 'S20USSIBAR', 'S20USSISTO', 'S20USSIGRE', 'G20PSCRSHA', 'G20PSCDBRY', 'G20PSCLMEL', 'G20PSCRMCD', 'G20PSCDBLA', 'G20PSCLWIL', 'R21USSRPER', 'R21USSDOSS', 'R21USSRLOE', 'R21USSDWAR', 'R21PSCRMCD', 'R21PSCDBLA']

# %% [markdown]
# ### Load Non-Recount Election Data

# %% [markdown]
# This data had to be downloaded county-by-county in XML format. The below code parses the XML and grabs the necessary data, adds it to a list, gives it the appropriate column names, and converts the data into a dataframe.

# %%
loaded_counties = os.listdir("./raw-from-source/official_county_results/")
z=[]
for locale in loaded_counties:
    print(locale)
    if locale.endswith('.xml'):
        file_string = "./raw-from-source/official_county_results/"+locale
        xtree = et.parse(file_string)
        xroot = xtree.getroot()
        store_list = []
        county_area = xroot.findall(".//Region")
        for i in county_area:
            county = i.text
        contests = xroot.findall(".//Contest")
        for i in contests:
            contest = i.attrib.get('text')
            lower = i.findall("./Choice")
            for j in lower:
                print(lower)
                choice = j.attrib.get('text')
                lower_2 = j.findall("./VoteType")
                for k in lower_2:
                    voting_method = k.attrib.get('name')
                    lower_3 = k.findall("./County")
                    print(lower_3)
                    for l in lower_3:
                        precinct_name = l.attrib.get('name')
                        num_votes = l.attrib.get('votes')
                        z.append([county,contest,choice,voting_method,precinct_name,num_votes,locale])
dfcols = ['state','contest','choice','voting_method','county','num_votes',"file"]
df_general = pd.DataFrame(z,columns=dfcols)
# Out:
# General_Election.xml
# [<Element 'Choice' at 0x177810db0>, <Element 'Choice' at 0x1751fcbd0>, <Element 'Choice' at 0x172964a90>]
# [<Element 'County' at 0x177810540>, <Element 'County' at 0x177810a90>, <Element 'County' at 0x177810cc0>, <Element 'County' at 0x177810f90>, <Element 'County' at 0x177802860>, <Element 'County' at 0x177802310>, <Element 'County' at 0x177802c70>, <Element 'County' at 0x1778020e0>, <Element 'County' at 0x177802360>, <Element 'County' at 0x177802540>, <Element 'County' at 0x177802720>, <Element 'County' at 0x177802900>, <Element 'County' at 0x177802ae0>, <Element 'County' at 0x177802cc0>, <Element 'County' at 0x177802ea0>, <Element 'County' at 0x177802e50>, <Element 'County' at 0x177802040>, <Element 'County' at 0x1778029a0>, <Element 'County' at 0x177802e00>, <Element 'County' at 0x1778026d0>, <Element 'County' at 0x1778021d0>, <Element 'County' at 0x177802220>, <Element 'County' at 0x177802770>, <Element 'County' at 0x17780bf40>, <Element 'County' at 0x17780b7c0>, <Element 'County' at 0x17780b040>, <Element 'County' at 0x17780b220>, <Element 'County' at 0x17780b4a0>, <Element 'County' at 0x17780b680>, <Element 'County' at 0x17780b860>, <Element 'County' at 0x17780ba40>, <Element 'County' at 0x17780bcc0>, <Element 'County' at 0x17780bb30>, <Element 'County' at 0x17780b180>, <Element 'County' at 0x17780b4f0>, <Element 'County' at 0x17780bb80>, <Element 'County' at 0x17780be00>, <Element 'County' at 0x17780b1d0>, <Element 'County' at 0x17780bd60>, <Element 'County' at 0x17780b360>, <Element 'County' at 0x17780b540>, <Element 'County' at 0x1777f2a90>, <Element 'County' at 0x1777f2c70>, <Element 'County' at 0x1777f2ef0>, <Element 'County' at 0x1777f2ae0>, <Element 'County' at 0x1777f2630>, <Element 'County' at 0x1777f23b0>, <Element 'County' at 0x1777f2a40>, <Element 'County' at 0x1777f2db0>, <Element 'County' at 0x1777f2540>, <Element 'County' at 0x1777f2810>, <Element 'County' at 0x1777f27c0>, <Element 'County' at 0x1777f2180>, <Element 'County' at 0x1777f2900>, <Element 'County' at 0x1777f20e0>, <Element 'County' at 0x1777f2b30>, <Element 'County' at 0x1777f2130>, <Element 'County' at 0x1777f2310>, <Element 'County' at 0x1777f24f0>, <Element 'County' at 0x1777f25e0>, <Element 'County' at 0x172cd5c70>, <Element 'County' at 0x172cd5c20>, <Element 'County' at 0x172cd5a90>, <Element 'County' at 0x172cd5a40>, <Element 'County' at 0x172cd58b0>, <Element 'County' at 0x172cd5860>, <Element 'County' at 0x172cd57c0>, <Element 'County' at 0x172cd54f0>, <Element 'County' at 0x172cd54a0>, <Element 'County' at 0x172cd53b0>, <Element 'County' at 0x172cd5220>, <Element 'County' at 0x172cd5270>, <Element 'County' at 0x172cd5090>, <Element 'County' at 0x172cd5400>, <Element 'County' at 0x172cd5d10>, <Element 'County' at 0x172cd5b30>, <Element 'County' at 0x172cd5950>, <Element 'County' at 0x172cd5770>, <Element 'County' at 0x172cd5590>, <Element 'County' at 0x172cd5360>, <Element 'County' at 0x172cd5180>, <Element 'County' at 0x172cd5450>, <Element 'County' at 0x172cd5810>, <Element 'County' at 0x172cd5e50>, <Element 'County' at 0x172cd5680>, <Element 'County' at 0x1749bda90>, <Element 'County' at 0x1749bddb0>, <Element 'County' at 0x1749bdd10>, <Element 'County' at 0x1749bdb80>, <Element 'County' at 0x1749bdb30>, <Element 'County' at 0x1749bd950>, <Element 'County' at 0x1749bd900>, <Element 'County' at 0x1749bd770>, <Element 'County' at 0x1749bd720>, <Element 'County' at 0x1749bd360>, <Element 'County' at 0x1749bd0e0>, <Element 'County' at 0x1749bd270>, <Element 'County' at 0x1749bd130>, <Element 'County' at 0x1749bd4f0>, <Element 'County' at 0x1749bd040>, <Element 'County' at 0x1749bdae0>, <Element 'County' at 0x1749bd8b0>, <Element 'County' at 0x1749bd6d0>, <Element 'County' at 0x1749bd450>, <Element 'County' at 0x1749bd220>, <Element 'County' at 0x1749bd4a0>, <Element 'County' at 0x1749bde00>, <Element 'County' at 0x1749bdef0>, <Element 'County' at 0x1749bd590>, <Element 'County' at 0x174267090>, <Element 'County' at 0x174267130>, <Element 'County' at 0x174267360>, <Element 'County' at 0x174267450>, <Element 'County' at 0x174267540>, <Element  ...
# [<Element 'County' at 0x175c8d400>, <Element 'County' at 0x175c8d4f0>, <Element 'County' at 0x175c8d6d0>, <Element 'County' at 0x175c8d680>, <Element 'County' at 0x175c8d810>, <Element 'County' at 0x175c8d9f0>, <Element 'County' at 0x175c8d9a0>, <Element 'County' at 0x175c8da40>, <Element 'County' at 0x175c8dc70>, <Element 'County' at 0x175c8ddb0>, <Element 'County' at 0x175c8de50>, <Element 'County' at 0x175c8d630>, <Element 'County' at 0x175c8d090>, <Element 'County' at 0x175c8d270>, <Element 'County' at 0x175c8d450>, <Element 'County' at 0x175c8d5e0>, <Element 'County' at 0x175c8d900>, <Element 'County' at 0x175c8dae0>, <Element 'County' at 0x175c8dcc0>, <Element 'County' at 0x175c8def0>, <Element 'County' at 0x175c8dbd0>, <Element 'County' at 0x175c8d720>, <Element 'County' at 0x1732bff90>, <Element 'County' at 0x1732bff40>, <Element 'County' at 0x1732bfe00>, <Element 'County' at 0x1732bfc70>, <Element 'County' at 0x1732bfbd0>, <Element 'County' at 0x1732bfb80>, <Element 'County' at 0x1732bfae0>, <Element 'County' at 0x1732bf900>, <Element 'County' at 0x1732bf860>, <Element 'County' at 0x1732bf6d0>, <Element 'County' at 0x1732bf680>, <Element 'County' at 0x1732bf5e0>, <Element 'County' at 0x1732bf450>, <Element 'County' at 0x1732bf040>, <Element 'County' at 0x1732bf360>, <Element 'County' at 0x1732bf9a0>, <Element 'County' at 0x1732bf2c0>, <Element 'County' at 0x1732bfd10>, <Element 'County' at 0x1732bf9f0>, <Element 'County' at 0x1732bf770>, <Element 'County' at 0x1732bf590>, <Element 'County' at 0x1732bf310>, <Element 'County' at 0x1732bf4f0>, <Element 'County' at 0x1760c7f40>, <Element 'County' at 0x1760c7d60>, <Element 'County' at 0x1760c7d10>, <Element 'County' at 0x1760c7c20>, <Element 'County' at 0x1760c7bd0>, <Element 'County' at 0x1760c7b30>, <Element 'County' at 0x1760c79a0>, <Element 'County' at 0x1760c7950>, <Element 'County' at 0x1760c77c0>, <Element 'County' at 0x1760c7450>, <Element 'County' at 0x1760c74a0>, <Element 'County' at 0x1760c7310>, <Element 'County' at 0x1760c7270>, <Element 'County' at 0x1760c7220>, <Element 'County' at 0x1760c7090>, <Element 'County' at 0x1760c7040>, <Element 'County' at 0x1760c7e00>, <Element 'County' at 0x1760c7b80>, <Element 'County' at 0x1760c7900>, <Element 'County' at 0x1760c7720>, <Element 'County' at 0x1760c7540>, <Element 'County' at 0x1760c71d0>, <Element 'County' at 0x1760c75e0>, <Element 'County' at 0x1760c7cc0>, <Element 'County' at 0x1760c7ef0>, <Element 'County' at 0x175a55e00>, <Element 'County' at 0x175a55c20>, <Element 'County' at 0x175a55a90>, <Element 'County' at 0x175a559f0>, <Element 'County' at 0x175a55900>, <Element 'County' at 0x175a55720>, <Element 'County' at 0x175a558b0>, <Element 'County' at 0x175a55400>, <Element 'County' at 0x175a553b0>, <Element 'County' at 0x175a55310>, <Element 'County' at 0x175a55180>, <Element 'County' at 0x175a55130>, <Element 'County' at 0x175a55090>, <Element 'County' at 0x175a55810>, <Element 'County' at 0x175a55590>, <Element 'County' at 0x175a55950>, <Element 'County' at 0x175a55ef0>, <Element 'County' at 0x175a55d60>, <Element 'County' at 0x175a55ae0>, <Element 'County' at 0x175a556d0>, <Element 'County' at 0x175a55450>, <Element 'County' at 0x175a55270>, <Element 'County' at 0x175a55360>, <Element 'County' at 0x175a55e50>, <Element 'County' at 0x172c3aae0>, <Element 'County' at 0x172c3a9a0>, <Element 'County' at 0x172c3aef0>, <Element 'County' at 0x172c3ad60>, <Element 'County' at 0x172c3ad10>, <Element 'County' at 0x172c3ab80>, <Element 'County' at 0x172c3acc0>, <Element 'County' at 0x172c3a770>, <Element 'County' at 0x172c3a6d0>, <Element 'County' at 0x172c3a680>, <Element 'County' at 0x172c3a4f0>, <Element 'County' at 0x172c3a5e0>, <Element 'County' at 0x172c3a2c0>, <Element 'County' at 0x172c3a0e0>, <Element 'County' at 0x172c3a040>, <Element 'County' at 0x172c3a130>, <Element 'County' at 0x172c3a220>, <Element 'County' at 0x172c3a400>, <Element 'County' at 0x172c3ae00>, <Element 'County' at 0x172c3ac20>, <Element  ...
# [<Element 'County' at 0x17224ab80>, <Element 'County' at 0x17224a1d0>, <Element 'County' at 0x17224acc0>, <Element 'County' at 0x17224af40>, <Element 'County' at 0x17224a900>, <Element 'County' at 0x17224a9a0>, <Element 'County' at 0x17224ab30>, <Element 'County' at 0x176e3bef0>, <Element 'County' at 0x176e3b270>, <Element 'County' at 0x176e3b180>, <Element 'County' at 0x176e3b090>, <Element 'County' at 0x176e3bcc0>, <Element 'County' at 0x176e3bd60>, <Element 'County' at 0x176e3bbd0>, <Element 'County' at 0x176e3bb80>, <Element 'County' at 0x176e3ba40>, <Element 'County' at 0x176e3b9a0>, <Element 'County' at 0x176e3b810>, <Element 'County' at 0x176e3b770>, <Element 'County' at 0x176e3b6d0>, <Element 'County' at 0x176e3b680>, <Element 'County' at 0x176e3b5e0>, <Element 'County' at 0x176e3bdb0>, <Element 'County' at 0x176e3bf40>, <Element 'County' at 0x176e3b4a0>, <Element 'County' at 0x176e3b900>, <Element 'County' at 0x176e3bc20>, <Element 'County' at 0x176e3be00>, <Element 'County' at 0x176e3b220>, <Element 'County' at 0x176e3b3b0>, <Element 'County' at 0x176e3b040>, <Element 'County' at 0x175ac9c20>, <Element 'County' at 0x175ac9a90>, <Element 'County' at 0x175ac9a40>, <Element 'County' at 0x175ac9860>, <Element 'County' at 0x175ac9540>, <Element 'County' at 0x175ac92c0>, <Element 'County' at 0x175ac91d0>, <Element 'County' at 0x175ac9090>, <Element 'County' at 0x175ac9450>, <Element 'County' at 0x175ac9b30>, <Element 'County' at 0x175ac9130>, <Element 'County' at 0x175ac9310>, <Element 'County' at 0x175ac9590>, <Element 'County' at 0x175ac9770>, <Element 'County' at 0x175ac99f0>, <Element 'County' at 0x175ac9bd0>, <Element 'County' at 0x175ac9e50>, <Element 'County' at 0x175ac9950>, <Element 'County' at 0x175ac93b0>, <Element 'County' at 0x175ac97c0>, <Element 'County' at 0x175ac9c70>, <Element 'County' at 0x175ac9720>, <Element 'County' at 0x175ac9ef0>, <Element 'County' at 0x175ac99a0>, <Element 'County' at 0x176e33c20>, <Element 'County' at 0x176e33f90>, <Element 'County' at 0x176e33d60>, <Element 'County' at 0x176e33cc0>, <Element 'County' at 0x176e33d10>, <Element 'County' at 0x176e33a90>, <Element 'County' at 0x176e33900>, <Element 'County' at 0x176e33860>, <Element 'County' at 0x176e337c0>, <Element 'County' at 0x176e336d0>, <Element 'County' at 0x176e33180>, <Element 'County' at 0x176e33400>, <Element 'County' at 0x176e33130>, <Element 'County' at 0x176e33ae0>, <Element 'County' at 0x176e33590>, <Element 'County' at 0x176e33090>, <Element 'County' at 0x176e33b30>, <Element 'County' at 0x176e339f0>, <Element 'County' at 0x176e33220>, <Element 'County' at 0x176e334f0>, <Element 'County' at 0x176e33950>, <Element 'County' at 0x176e33f40>, <Element 'County' at 0x176e332c0>, <Element 'County' at 0x176e33ef0>, <Element 'County' at 0x176eb0720>, <Element 'County' at 0x176eb0d10>, <Element 'County' at 0x176eb0cc0>, <Element 'County' at 0x176eb0b30>, <Element 'County' at 0x176eb0c20>, <Element 'County' at 0x176eb0860>, <Element 'County' at 0x176eb07c0>, <Element 'County' at 0x176eb0630>, <Element 'County' at 0x176eb0590>, <Element 'County' at 0x176eb0540>, <Element 'County' at 0x176eb03b0>, <Element 'County' at 0x176eb0310>, <Element 'County' at 0x176eb0270>, <Element 'County' at 0x176eb0040>, <Element 'County' at 0x176eb0090>, <Element 'County' at 0x176eb0220>, <Element 'County' at 0x176eb0e50>, <Element 'County' at 0x176eb0130>, <Element 'County' at 0x176eb01d0>, <Element 'County' at 0x176eb04f0>, <Element 'County' at 0x176eb08b0>, <Element 'County' at 0x176eb04a0>, <Element 'County' at 0x176eb0900>, <Element 'County' at 0x176eb0bd0>, <Element 'County' at 0x176eb09a0>, <Element 'County' at 0x1723f31d0>, <Element 'County' at 0x1723f3270>, <Element 'County' at 0x1723f3310>, <Element 'County' at 0x1723f35e0>, <Element 'County' at 0x1723f3630>, <Element 'County' at 0x1723f38b0>, <Element 'County' at 0x1723f3950>, <Element 'County' at 0x1723f3bd0>, <Element 'County' at 0x1723f3c20>, <Element 'County' at 0x1723f3e00>, <Element  ...
# [<Element 'County' at 0x1723c6a90>, <Element 'County' at 0x1723c69a0>, <Element 'County' at 0x1723c6a40>, <Element 'County' at 0x1723c6ae0>, <Element 'County' at 0x1723c6b80>, <Element 'County' at 0x1723c6c20>, <Element 'County' at 0x1723c6cc0>, <Element 'County' at 0x1723c6ea0>, <Element 'County' at 0x1723c68b0>, <Element 'County' at 0x1723c6900>, <Element 'County' at 0x1723c6f40>, <Element 'County' at 0x1723c6860>, <Element 'County' at 0x1723c6e00>, <Element 'County' at 0x1723c6270>, <Element 'County' at 0x1723c6ef0>, <Element 'County' at 0x1723c6040>, <Element 'County' at 0x17286da90>, <Element 'County' at 0x17286de00>, <Element 'County' at 0x17286db30>, <Element 'County' at 0x17286dc70>, <Element 'County' at 0x17286da40>, <Element 'County' at 0x17286d9a0>, <Element 'County' at 0x17286d900>, <Element 'County' at 0x17286d860>, <Element 'County' at 0x17286d770>, <Element 'County' at 0x17286d680>, <Element 'County' at 0x17286d5e0>, <Element 'County' at 0x17286d400>, <Element 'County' at 0x17286d180>, <Element 'County' at 0x17286d130>, <Element 'County' at 0x17286d090>, <Element 'County' at 0x17286d1d0>, <Element 'County' at 0x17286dcc0>, <Element 'County' at 0x17286de50>, <Element 'County' at 0x17286d3b0>, <Element 'County' at 0x17286d220>, <Element 'County' at 0x17286d360>, <Element 'County' at 0x17286d7c0>, <Element 'County' at 0x17286d450>, <Element 'County' at 0x17286dd60>, <Element 'County' at 0x1723e4540>, <Element 'County' at 0x1723e4270>, <Element 'County' at 0x1723e4220>, <Element 'County' at 0x1723e4310>, <Element 'County' at 0x1723e43b0>, <Element 'County' at 0x1723e48b0>, <Element 'County' at 0x1723e4680>, <Element 'County' at 0x1723e46d0>, <Element 'County' at 0x1723e4a40>, <Element 'County' at 0x1723e4b80>, <Element 'County' at 0x1723e4c20>, <Element 'County' at 0x1723e4bd0>, <Element 'County' at 0x1723e4ea0>, <Element 'County' at 0x1723e4f40>, <Element 'County' at 0x1723e4590>, <Element 'County' at 0x1723e40e0>, <Element 'County' at 0x1723e4130>, <Element 'County' at 0x1723e4d60>, <Element 'County' at 0x1723e4860>, <Element 'County' at 0x1723e4db0>, <Element 'County' at 0x1723e41d0>, <Element 'County' at 0x1723e4770>, <Element 'County' at 0x1723e49f0>, <Element 'County' at 0x1723e4b30>, <Element 'County' at 0x1723e4630>, <Element 'County' at 0x176d3fd10>, <Element 'County' at 0x176d3ff40>, <Element 'County' at 0x176d3f590>, <Element 'County' at 0x176d3fae0>, <Element 'County' at 0x176d3fa40>, <Element 'County' at 0x176d3f950>, <Element 'County' at 0x176d3f860>, <Element 'County' at 0x176d3f7c0>, <Element 'County' at 0x176d3f720>, <Element 'County' at 0x176d3f770>, <Element 'County' at 0x176d3f6d0>, <Element 'County' at 0x176d3f630>, <Element 'County' at 0x176d3f310>, <Element 'County' at 0x176d3f540>, <Element 'County' at 0x176d3f130>, <Element 'County' at 0x176d3f4f0>, <Element 'County' at 0x176d3f090>, <Element 'County' at 0x176d3f360>, <Element 'County' at 0x176d3f4a0>, <Element 'County' at 0x176d3fcc0>, <Element 'County' at 0x176d3f9a0>, <Element 'County' at 0x176d3fea0>, <Element 'County' at 0x176d3f220>, <Element 'County' at 0x176d3fc20>, <Element 'County' at 0x176dcd2c0>, <Element 'County' at 0x176dcdef0>, <Element 'County' at 0x176dcdd60>, <Element 'County' at 0x176dcdbd0>, <Element 'County' at 0x176dcda40>, <Element 'County' at 0x176dcd950>, <Element 'County' at 0x176dcd900>, <Element 'County' at 0x176dcd810>, <Element 'County' at 0x176dcd720>, <Element 'County' at 0x176dcd630>, <Element 'County' at 0x176dcd590>, <Element 'County' at 0x176dcd450>, <Element 'County' at 0x176dcd040>, <Element 'County' at 0x176dcd090>, <Element 'County' at 0x176dcd540>, <Element 'County' at 0x176dcd220>, <Element 'County' at 0x176dcd3b0>, <Element 'County' at 0x176dcddb0>, <Element 'County' at 0x176dcd0e0>, <Element 'County' at 0x176dcdea0>, <Element 'County' at 0x176dcd9a0>, <Element 'County' at 0x176dcd130>, <Element 'County' at 0x176dcd5e0>, <Element 'County' at 0x176dcde50>, <Element 'County' at 0x176dcdc20>, <Element  ...
# [<Element 'Choice' at 0x177810db0>, <Element 'Choice' at 0x1751fcbd0>, <Element 'Choice' at 0x172964a90>]
# [<Element 'County' at 0x1751fc540>, <Element 'County' at 0x173f8e400>, <Element 'County' at 0x173f8e4f0>, <Element 'County' at 0x173f8e590>, <Element 'County' at 0x173f8e8b0>, <Element 'County' at 0x173f8e090>, <Element 'County' at 0x173f8e680>, <Element 'County' at 0x173f8ecc0>, <Element 'County' at 0x173f8ee50>, <Element 'County' at 0x173f8e950>, <Element 'County' at 0x173f8edb0>, <Element 'County' at 0x173f8e630>, <Element 'County' at 0x173f8e0e0>, <Element 'County' at 0x173f8e3b0>, <Element 'County' at 0x173f8ee00>, <Element 'County' at 0x173f8e220>, <Element 'County' at 0x173f8ec20>, <Element 'County' at 0x173f8ea40>, <Element 'County' at 0x173f8eef0>, <Element 'County' at 0x173f8ec70>, <Element 'County' at 0x173f8ef40>, <Element 'County' at 0x173f8eb80>, <Element 'County' at 0x173f8e310>, <Element 'County' at 0x173f8e450>, <Element 'County' at 0x173f8e9a0>, <Element 'County' at 0x16ebf66d0>, <Element 'County' at 0x16ebf6310>, <Element 'County' at 0x16ebf62c0>, <Element 'County' at 0x16ebf60e0>, <Element 'County' at 0x16ebf6720>, <Element 'County' at 0x16ebf6ea0>, <Element 'County' at 0x16ebf6590>, <Element 'County' at 0x16ebf64a0>, <Element 'County' at 0x16ebf64f0>, <Element 'County' at 0x16ebf68b0>, <Element 'County' at 0x16ebf6a40>, <Element 'County' at 0x16ebf6040>, <Element 'County' at 0x16ebf65e0>, <Element 'County' at 0x16ebf6450>, <Element 'County' at 0x16ebf63b0>, <Element 'County' at 0x16ebf6c20>, <Element 'County' at 0x16ebf6db0>, <Element 'County' at 0x16ebf67c0>, <Element 'County' at 0x16ebf6900>, <Element 'County' at 0x16ebf6ef0>, <Element 'County' at 0x16ebf6540>, <Element 'County' at 0x16ebf6e00>, <Element 'County' at 0x16ebf6130>, <Element 'County' at 0x16ebf6a90>, <Element 'County' at 0x16ec2e4f0>, <Element 'County' at 0x16ec2e6d0>, <Element 'County' at 0x16ec2ecc0>, <Element 'County' at 0x16ec2e720>, <Element 'County' at 0x16ec2eea0>, <Element 'County' at 0x16ec2e3b0>, <Element 'County' at 0x16ec2ed60>, <Element 'County' at 0x16ec2ee50>, <Element 'County' at 0x16ec2e450>, <Element 'County' at 0x16ec2e310>, <Element 'County' at 0x16ec2e5e0>, <Element 'County' at 0x16ec2ea90>, <Element 'County' at 0x16ec2e090>, <Element 'County' at 0x16ec2e8b0>, <Element 'County' at 0x16ec2e590>, <Element 'County' at 0x16ec2e860>, <Element 'County' at 0x16ec2eb80>, <Element 'County' at 0x16ec2ef40>, <Element 'County' at 0x16ec2e040>, <Element 'County' at 0x16ec2e1d0>, <Element 'County' at 0x16ec2ef90>, <Element 'County' at 0x16ec2e400>, <Element 'County' at 0x16ec2e770>, <Element 'County' at 0x16ec2ee00>, <Element 'County' at 0x172cfd0e0>, <Element 'County' at 0x172cfd1d0>, <Element 'County' at 0x172cfd270>, <Element 'County' at 0x172cfd360>, <Element 'County' at 0x172cfd5e0>, <Element 'County' at 0x172cfd6d0>, <Element 'County' at 0x172cfda40>, <Element 'County' at 0x172cfdc20>, <Element 'County' at 0x172cfdcc0>, <Element 'County' at 0x172cfddb0>, <Element 'County' at 0x172cfd8b0>, <Element 'County' at 0x172cfd400>, <Element 'County' at 0x172cfd180>, <Element 'County' at 0x172cfd4a0>, <Element 'County' at 0x172cfd680>, <Element 'County' at 0x172cfd860>, <Element 'County' at 0x172cfdb80>, <Element 'County' at 0x172cfdd60>, <Element 'County' at 0x172cfdf40>, <Element 'County' at 0x172cfdb30>, <Element 'County' at 0x172cfd540>, <Element 'County' at 0x172cfd9f0>, <Element 'County' at 0x172cfd720>, <Element 'County' at 0x172cfd040>, <Element 'County' at 0x172cfdae0>, <Element 'County' at 0x1730022c0>, <Element 'County' at 0x1730029a0>, <Element 'County' at 0x173002c70>, <Element 'County' at 0x173002f40>, <Element 'County' at 0x173002db0>, <Element 'County' at 0x173002040>, <Element 'County' at 0x1730020e0>, <Element 'County' at 0x173002b30>, <Element 'County' at 0x173002310>, <Element 'County' at 0x1730025e0>, <Element 'County' at 0x173002810>, <Element 'County' at 0x173002900>, <Element 'County' at 0x1730029f0>, <Element 'County' at 0x1730024f0>, <Element 'County' at 0x173002d60>, <Element 'County' at 0x173002f90>, <Element  ...
# [<Element 'County' at 0x1770ad860>, <Element 'County' at 0x1770ad3b0>, <Element 'County' at 0x1770ad180>, <Element 'County' at 0x1770adae0>, <Element 'County' at 0x1770ade00>, <Element 'County' at 0x1770ad220>, <Element 'County' at 0x1770ad5e0>, <Element 'County' at 0x1770ada90>, <Element 'County' at 0x1770ad4a0>, <Element 'County' at 0x1770ad9a0>, <Element 'County' at 0x177008130>, <Element 'County' at 0x177008090>, <Element 'County' at 0x177008f40>, <Element 'County' at 0x177008ea0>, <Element 'County' at 0x177008e50>, <Element 'County' at 0x177008b30>, <Element 'County' at 0x1770089f0>, <Element 'County' at 0x1770088b0>, <Element 'County' at 0x177008810>, <Element 'County' at 0x1770086d0>, <Element 'County' at 0x177008720>, <Element 'County' at 0x1770084f0>, <Element 'County' at 0x1770084a0>, <Element 'County' at 0x1770083b0>, <Element 'County' at 0x177008310>, <Element 'County' at 0x177008e00>, <Element 'County' at 0x177008db0>, <Element 'County' at 0x177008770>, <Element 'County' at 0x177008a90>, <Element 'County' at 0x177008c70>, <Element 'County' at 0x1770080e0>, <Element 'County' at 0x177008270>, <Element 'County' at 0x177008180>, <Element 'County' at 0x177008220>, <Element 'County' at 0x1770a4e50>, <Element 'County' at 0x1770a4ef0>, <Element 'County' at 0x1770a4a90>, <Element 'County' at 0x1770a49f0>, <Element 'County' at 0x1770a4860>, <Element 'County' at 0x1770a47c0>, <Element 'County' at 0x1770a4630>, <Element 'County' at 0x1770a4590>, <Element 'County' at 0x1770a4540>, <Element 'County' at 0x1770a44a0>, <Element 'County' at 0x1770a4310>, <Element 'County' at 0x1770a4400>, <Element 'County' at 0x1770a4360>, <Element 'County' at 0x1770a4ae0>, <Element 'County' at 0x1770a4e00>, <Element 'County' at 0x1770a4a40>, <Element 'County' at 0x1770a4cc0>, <Element 'County' at 0x1770a43b0>, <Element 'County' at 0x1770a46d0>, <Element 'County' at 0x1770a4900>, <Element 'County' at 0x1770a4ea0>, <Element 'County' at 0x1770a4040>, <Element 'County' at 0x1770a4db0>, <Element 'County' at 0x1770a4f40>, <Element 'County' at 0x1770a4270>, <Element 'County' at 0x17700def0>, <Element 'County' at 0x17700de00>, <Element 'County' at 0x17700ddb0>, <Element 'County' at 0x17700db80>, <Element 'County' at 0x17700da90>, <Element 'County' at 0x17700d9f0>, <Element 'County' at 0x17700d950>, <Element 'County' at 0x17700d860>, <Element 'County' at 0x17700d680>, <Element 'County' at 0x17700d590>, <Element 'County' at 0x17700d4a0>, <Element 'County' at 0x17700d3b0>, <Element 'County' at 0x17700d310>, <Element 'County' at 0x17700d220>, <Element 'County' at 0x17700d180>, <Element 'County' at 0x17700d040>, <Element 'County' at 0x17700d7c0>, <Element 'County' at 0x17700dbd0>, <Element 'County' at 0x17700d2c0>, <Element 'County' at 0x17700d540>, <Element 'County' at 0x17700d8b0>, <Element 'County' at 0x17700dc20>, <Element 'County' at 0x17700d770>, <Element 'County' at 0x17700de50>, <Element 'County' at 0x17706bb80>, <Element 'County' at 0x17706b360>, <Element 'County' at 0x17706bd10>, <Element 'County' at 0x17706bd60>, <Element 'County' at 0x17706bc70>, <Element 'County' at 0x17706bb30>, <Element 'County' at 0x17706b900>, <Element 'County' at 0x17706b950>, <Element 'County' at 0x17706b720>, <Element 'County' at 0x17706b4f0>, <Element 'County' at 0x17706b400>, <Element 'County' at 0x17706b1d0>, <Element 'County' at 0x17706b310>, <Element 'County' at 0x17706bef0>, <Element 'County' at 0x17706b770>, <Element 'County' at 0x17706b680>, <Element 'County' at 0x17706b270>, <Element 'County' at 0x17706b3b0>, <Element 'County' at 0x17706b860>, <Element 'County' at 0x17706bbd0>, <Element 'County' at 0x17706bdb0>, <Element 'County' at 0x17706b450>, <Element 'County' at 0x17706bcc0>, <Element 'County' at 0x17706b810>, <Element 'County' at 0x176fbee50>, <Element 'County' at 0x176fbedb0>, <Element 'County' at 0x176fbeb80>, <Element 'County' at 0x176fbe900>, <Element 'County' at 0x176fbe360>, <Element 'County' at 0x176fbe6d0>, <Element 'County' at 0x176fbe770>, <Element  ...
# [<Element 'County' at 0x176f29b30>, <Element 'County' at 0x176f29a90>, <Element 'County' at 0x176f29900>, <Element 'County' at 0x176f29770>, <Element 'County' at 0x176f295e0>, <Element 'County' at 0x176f294a0>, <Element 'County' at 0x176f29400>, <Element 'County' at 0x176f29310>, <Element 'County' at 0x176f291d0>, <Element 'County' at 0x176f29130>, <Element 'County' at 0x176f29040>, <Element 'County' at 0x176f29590>, <Element 'County' at 0x176f29f90>, <Element 'County' at 0x176f299f0>, <Element 'County' at 0x176f29270>, <Element 'County' at 0x176f290e0>, <Element 'County' at 0x176f29540>, <Element 'County' at 0x176f297c0>, <Element 'County' at 0x176f29ae0>, <Element 'County' at 0x176f29e50>, <Element 'County' at 0x1753fe8b0>, <Element 'County' at 0x1753fe130>, <Element 'County' at 0x1753fe630>, <Element 'County' at 0x1753fea40>, <Element 'County' at 0x1753fe9f0>, <Element 'County' at 0x1753fe9a0>, <Element 'County' at 0x1753fef40>, <Element 'County' at 0x1753fe270>, <Element 'County' at 0x1753fef90>, <Element 'County' at 0x1753fed10>, <Element 'County' at 0x1753feb30>, <Element 'County' at 0x1753fe900>, <Element 'County' at 0x1753fe450>, <Element 'County' at 0x1753fe1d0>, <Element 'County' at 0x1753fe680>, <Element 'County' at 0x1753fedb0>, <Element 'County' at 0x1753fe7c0>, <Element 'County' at 0x1753fec70>, <Element 'County' at 0x1753fe090>, <Element 'County' at 0x1753fe810>, <Element 'County' at 0x1753fea90>, <Element 'County' at 0x1753fe4f0>, <Element 'County' at 0x1753fee50>, <Element 'County' at 0x1753febd0>, <Element 'County' at 0x17231ce00>, <Element 'County' at 0x17231c400>, <Element 'County' at 0x17231c270>, <Element 'County' at 0x17231c360>, <Element 'County' at 0x17231cbd0>, <Element 'County' at 0x17231c4f0>, <Element 'County' at 0x17231cd60>, <Element 'County' at 0x17231c0e0>, <Element 'County' at 0x17231c9a0>, <Element 'County' at 0x17231c2c0>, <Element 'County' at 0x17231cf40>, <Element 'County' at 0x17231c130>, <Element 'County' at 0x17231c770>, <Element 'County' at 0x17231c680>, <Element 'County' at 0x17231c3b0>, <Element 'County' at 0x17231cb30>, <Element 'County' at 0x17231c720>, <Element 'County' at 0x17231c540>, <Element 'County' at 0x17231c6d0>, <Element 'County' at 0x17231cf90>, <Element 'County' at 0x17231cc20>, <Element 'County' at 0x17231c220>, <Element 'County' at 0x17231ce50>, <Element 'County' at 0x17231c630>, <Element 'County' at 0x17231ca90>, <Element 'County' at 0x16fd53c20>, <Element 'County' at 0x16fd53130>, <Element 'County' at 0x16fd53400>, <Element 'County' at 0x16fd53180>, <Element 'County' at 0x16fd53720>, <Element 'County' at 0x16fd53c70>, <Element 'County' at 0x16fd53040>, <Element 'County' at 0x16fd53d60>, <Element 'County' at 0x16fd53f90>, <Element 'County' at 0x16fd53590>, <Element 'County' at 0x16fd53a40>, <Element 'County' at 0x16fd53540>, <Element 'County' at 0x16fd53ae0>, <Element 'County' at 0x16fd53b30>, <Element 'County' at 0x16fd539f0>, <Element 'County' at 0x16fd53e00>, <Element 'County' at 0x16fd53680>, <Element 'County' at 0x16fd531d0>, <Element 'County' at 0x16fd53810>, <Element 'County' at 0x16fd532c0>, <Element 'County' at 0x16fd53e50>, <Element 'County' at 0x16fd53db0>, <Element 'County' at 0x16fd534f0>, <Element 'County' at 0x16fd53090>, <Element 'County' at 0x175f1da40>, <Element 'County' at 0x175f1dc20>, <Element 'County' at 0x175f1de00>, <Element 'County' at 0x175f1d130>, <Element 'County' at 0x175f1d360>, <Element 'County' at 0x175f1d950>, <Element 'County' at 0x175f1d630>, <Element 'County' at 0x175f1d450>, <Element 'County' at 0x175f1df90>, <Element 'County' at 0x175f1dd60>, <Element 'County' at 0x175f1db80>, <Element 'County' at 0x175f1d900>, <Element 'County' at 0x175f1d720>, <Element 'County' at 0x175f1d4a0>, <Element 'County' at 0x175f1d2c0>, <Element 'County' at 0x175f1d4f0>, <Element 'County' at 0x175f1da90>, <Element 'County' at 0x175f1d6d0>, <Element 'County' at 0x175f1def0>, <Element 'County' at 0x175f1ddb0>, <Element 'County' at 0x175f1d220>, <Element  ...
# [<Element 'County' at 0x174ffc1d0>, <Element 'County' at 0x174ffca90>, <Element 'County' at 0x174ffccc0>, <Element 'County' at 0x174ffc9f0>, <Element 'County' at 0x174ffc7c0>, <Element 'County' at 0x174ffc180>, <Element 'County' at 0x174877d60>, <Element 'County' at 0x174877a90>, <Element 'County' at 0x1748779f0>, <Element 'County' at 0x174877680>, <Element 'County' at 0x1748775e0>, <Element 'County' at 0x174877590>, <Element 'County' at 0x174877450>, <Element 'County' at 0x174877310>, <Element 'County' at 0x1748774f0>, <Element 'County' at 0x1748772c0>, <Element 'County' at 0x174877d10>, <Element 'County' at 0x174877db0>, <Element 'County' at 0x174877900>, <Element 'County' at 0x174877720>, <Element 'County' at 0x174877400>, <Element 'County' at 0x174877180>, <Element 'County' at 0x174877040>, <Element 'County' at 0x1748776d0>, <Element 'County' at 0x174877a40>, <Element 'County' at 0x174877f90>, <Element 'County' at 0x174877c20>, <Element 'County' at 0x174877950>, <Element 'County' at 0x1748774a0>, <Element 'County' at 0x174877090>, <Element 'County' at 0x17346b540>, <Element 'County' at 0x17346b860>, <Element 'County' at 0x17346b8b0>, <Element 'County' at 0x17346bdb0>, <Element 'County' at 0x17346b950>, <Element 'County' at 0x17346be00>, <Element 'County' at 0x17346bd10>, <Element 'County' at 0x17346b770>, <Element 'County' at 0x17346bbd0>, <Element 'County' at 0x17346b1d0>, <Element 'County' at 0x17346b400>, <Element 'County' at 0x17346b5e0>, <Element 'County' at 0x17346b7c0>, <Element 'County' at 0x17346ba40>, <Element 'County' at 0x17346bc70>, <Element 'County' at 0x17346be50>, <Element 'County' at 0x17346b900>, <Element 'County' at 0x17346b360>, <Element 'County' at 0x17346bb80>, <Element 'County' at 0x17346b310>, <Element 'County' at 0x17346b6d0>, <Element 'County' at 0x17346bae0>, <Element 'County' at 0x17346bf90>, <Element 'County' at 0x17346bd60>, <Element 'County' at 0x1754becc0>, <Element 'County' at 0x1754bec20>, <Element 'County' at 0x1754bea90>, <Element 'County' at 0x1754be810>, <Element 'County' at 0x1754be6d0>, <Element 'County' at 0x1754be5e0>, <Element 'County' at 0x1754be450>, <Element 'County' at 0x1754be1d0>, <Element 'County' at 0x1754bec70>, <Element 'County' at 0x1754be360>, <Element 'County' at 0x1754bef90>, <Element 'County' at 0x1754bedb0>, <Element 'County' at 0x1754beae0>, <Element 'County' at 0x1754be900>, <Element 'County' at 0x1754be720>, <Element 'County' at 0x1754be540>, <Element 'County' at 0x1754be270>, <Element 'County' at 0x1754be180>, <Element 'County' at 0x1754beea0>, <Element 'County' at 0x1754beb30>, <Element 'County' at 0x1754be8b0>, <Element 'County' at 0x1754be4f0>, <Element 'County' at 0x1754be310>, <Element 'County' at 0x1754be090>, <Element 'County' at 0x1754be220>, <Element 'County' at 0x1776827c0>, <Element 'County' at 0x177682040>, <Element 'County' at 0x177682270>, <Element 'County' at 0x177682360>, <Element 'County' at 0x177682400>, <Element 'County' at 0x1776826d0>, <Element 'County' at 0x1776828b0>, <Element 'County' at 0x177682a90>, <Element 'County' at 0x177682d10>, <Element 'County' at 0x177682e00>, <Element 'County' at 0x177682ef0>, <Element 'County' at 0x177682f90>, <Element 'County' at 0x177682810>, <Element 'County' at 0x1776825e0>, <Element 'County' at 0x1776821d0>, <Element 'County' at 0x1776823b0>, <Element 'County' at 0x177682590>, <Element 'County' at 0x177682770>, <Element 'County' at 0x177682950>, <Element 'County' at 0x177682c70>, <Element 'County' at 0x177682e50>, <Element 'County' at 0x177682a40>, <Element 'County' at 0x177682180>, <Element 'County' at 0x177682720>, <Element 'County' at 0x172c38ef0>, <Element 'County' at 0x172c38e50>, <Element 'County' at 0x172c38db0>, <Element 'County' at 0x172c38d10>, <Element 'County' at 0x172c38c70>, <Element 'County' at 0x172c38bd0>, <Element 'County' at 0x172c38b80>, <Element 'County' at 0x172c389f0>, <Element 'County' at 0x172c38950>, <Element 'County' at 0x172c388b0>, <Element 'County' at 0x172c38810>, <Element  ...
# [<Element 'Choice' at 0x177810db0>, <Element 'Choice' at 0x1751fcbd0>, <Element 'Choice' at 0x172964a90>]
# [<Element 'County' at 0x172964950>, <Element 'County' at 0x1729648b0>, <Element 'County' at 0x172964810>, <Element 'County' at 0x172964770>, <Element 'County' at 0x1729646d0>, <Element 'County' at 0x172964630>, <Element 'County' at 0x172964590>, <Element 'County' at 0x1729644f0>, <Element 'County' at 0x172964450>, <Element 'County' at 0x1729643b0>, <Element 'County' at 0x172964310>, <Element 'County' at 0x172964270>, <Element 'County' at 0x1729641d0>, <Element 'County' at 0x172964130>, <Element 'County' at 0x172964090>, <Element 'County' at 0x1777ec630>, <Element 'County' at 0x1777ecae0>, <Element 'County' at 0x1777ec040>, <Element 'County' at 0x1777ec220>, <Element 'County' at 0x1777ec400>, <Element 'County' at 0x1777ec680>, <Element 'County' at 0x1777ec9a0>, <Element 'County' at 0x1777ecc20>, <Element 'County' at 0x1777ecea0>, <Element 'County' at 0x1777ec950>, <Element 'County' at 0x1777ec360>, <Element 'County' at 0x1777ec5e0>, <Element 'County' at 0x1777ecbd0>, <Element 'County' at 0x1777ecd60>, <Element 'County' at 0x1777ecef0>, <Element 'County' at 0x1777eca90>, <Element 'County' at 0x1777eca40>, <Element 'County' at 0x1777ec860>, <Element 'County' at 0x1777f6a40>, <Element 'County' at 0x1777f6bd0>, <Element 'County' at 0x1777f6cc0>, <Element 'County' at 0x1777f6130>, <Element 'County' at 0x1777f6310>, <Element 'County' at 0x1777f64f0>, <Element 'County' at 0x1777f66d0>, <Element 'County' at 0x1777f68b0>, <Element 'County' at 0x1777f6a90>, <Element 'County' at 0x1777f6d10>, <Element 'County' at 0x1777f6f90>, <Element 'County' at 0x1777f6680>, <Element 'County' at 0x1777f6090>, <Element 'County' at 0x1777f69f0>, <Element 'County' at 0x1777f6b80>, <Element 'County' at 0x1777f6e50>, <Element 'County' at 0x1777f6540>, <Element 'County' at 0x1777f62c0>, <Element 'County' at 0x1776c9c70>, <Element 'County' at 0x1776c9ef0>, <Element 'County' at 0x1776c9220>, <Element 'County' at 0x1776c9540>, <Element 'County' at 0x1776c9720>, <Element 'County' at 0x1776c99a0>, <Element 'County' at 0x1776c9b80>, <Element 'County' at 0x1776c9ea0>, <Element 'County' at 0x1776c96d0>, <Element 'County' at 0x1776c9450>, <Element 'County' at 0x1776c9040>, <Element 'County' at 0x1776c9360>, <Element 'County' at 0x1776c9680>, <Element 'County' at 0x1776c9ae0>, <Element 'County' at 0x1776c9d60>, <Element 'County' at 0x1776c94f0>, <Element 'County' at 0x1776c9950>, <Element 'County' at 0x1776c9cc0>, <Element 'County' at 0x1776f3680>, <Element 'County' at 0x1776f38b0>, <Element 'County' at 0x1776f3180>, <Element 'County' at 0x1776f3360>, <Element 'County' at 0x1776f3540>, <Element 'County' at 0x1776f3720>, <Element 'County' at 0x1776f3900>, <Element 'County' at 0x1776f3ae0>, <Element 'County' at 0x1776f3e00>, <Element 'County' at 0x1776f3ea0>, <Element 'County' at 0x1776f3040>, <Element 'County' at 0x1776f32c0>, <Element 'County' at 0x1776f37c0>, <Element 'County' at 0x1776f3a90>, <Element 'County' at 0x1776f3db0>, <Element 'County' at 0x1776f3130>, <Element 'County' at 0x1776f39a0>, <Element 'County' at 0x1776f3ef0>, <Element 'County' at 0x17783ed60>, <Element 'County' at 0x17783ebd0>, <Element 'County' at 0x17783eae0>, <Element 'County' at 0x17783e1d0>, <Element 'County' at 0x17783e450>, <Element 'County' at 0x17783e770>, <Element 'County' at 0x17783e950>, <Element 'County' at 0x17783eb30>, <Element 'County' at 0x17783edb0>, <Element 'County' at 0x17783e9f0>, <Element 'County' at 0x17783e180>, <Element 'County' at 0x17783e130>, <Element 'County' at 0x17783e8b0>, <Element 'County' at 0x17783ea90>, <Element 'County' at 0x177826130>, <Element 'County' at 0x177826540>, <Element 'County' at 0x177826180>, <Element 'County' at 0x1778261d0>, <Element 'County' at 0x1778263b0>, <Element 'County' at 0x177826630>, <Element 'County' at 0x177826810>, <Element 'County' at 0x177826b30>, <Element 'County' at 0x177826db0>, <Element 'County' at 0x177826900>, <Element 'County' at 0x177826360>, <Element 'County' at 0x1778266d0>, <Element 'County' at 0x177826950>, <Element  ...
# [<Element 'County' at 0x1776d0e00>, <Element 'County' at 0x1776d0ae0>, <Element 'County' at 0x1776d0ea0>, <Element 'County' at 0x164b50630>, <Element 'County' at 0x164b509f0>, <Element 'County' at 0x164b50a90>, <Element 'County' at 0x10d91d310>, <Element 'County' at 0x16eb81a40>, <Element 'County' at 0x16eb81f40>, <Element 'County' at 0x16eb81ef0>, <Element 'County' at 0x16eb81f90>, <Element 'County' at 0x16eb81e50>, <Element 'County' at 0x16eb819f0>, <Element 'County' at 0x16eb81bd0>, <Element 'County' at 0x175616630>, <Element 'County' at 0x1756162c0>, <Element 'County' at 0x175616f40>, <Element 'County' at 0x175616f90>, <Element 'County' at 0x175616c70>, <Element 'County' at 0x175616450>, <Element 'County' at 0x1756167c0>, <Element 'County' at 0x1756161d0>, <Element 'County' at 0x1756168b0>, <Element 'County' at 0x175616220>, <Element 'County' at 0x1756169f0>, <Element 'County' at 0x175616bd0>, <Element 'County' at 0x175616e50>, <Element 'County' at 0x175616810>, <Element 'County' at 0x175616270>, <Element 'County' at 0x1756164f0>, <Element 'County' at 0x175616b30>, <Element 'County' at 0x175616540>, <Element 'County' at 0x10f1bed10>, <Element 'County' at 0x10f1bef90>, <Element 'County' at 0x10f1be860>, <Element 'County' at 0x10f1be9f0>, <Element 'County' at 0x17564d360>, <Element 'County' at 0x17564dd10>, <Element 'County' at 0x17564ddb0>, <Element 'County' at 0x17564d450>, <Element 'County' at 0x17564dc70>, <Element 'County' at 0x17564d2c0>, <Element 'County' at 0x17564de50>, <Element 'County' at 0x17564db30>, <Element 'County' at 0x17564d950>, <Element 'County' at 0x17564d770>, <Element 'County' at 0x17564d590>, <Element 'County' at 0x17564d310>, <Element 'County' at 0x17564d130>, <Element 'County' at 0x17564d900>, <Element 'County' at 0x17564df90>, <Element 'County' at 0x17564def0>, <Element 'County' at 0x17564d720>, <Element 'County' at 0x17564d4f0>, <Element 'County' at 0x17564d680>, <Element 'County' at 0x17564d4a0>, <Element 'County' at 0x17564d0e0>, <Element 'County' at 0x17564dae0>, <Element 'County' at 0x17564d8b0>, <Element 'County' at 0x1749bf450>, <Element 'County' at 0x1749bf130>, <Element 'County' at 0x1749bf3b0>, <Element 'County' at 0x1749bf6d0>, <Element 'County' at 0x1749bf8b0>, <Element 'County' at 0x1749bfa90>, <Element 'County' at 0x1749bfc70>, <Element 'County' at 0x1749bfef0>, <Element 'County' at 0x1749bf9f0>, <Element 'County' at 0x1749bf0e0>, <Element 'County' at 0x1749bf540>, <Element 'County' at 0x1749bf770>, <Element 'County' at 0x1749bfb30>, <Element 'County' at 0x1749bff90>, <Element 'County' at 0x1749bf180>, <Element 'County' at 0x1749bf310>, <Element 'County' at 0x1749bf4f0>, <Element 'County' at 0x1749bf810>, <Element 'County' at 0x1749bff40>, <Element 'County' at 0x176aaff90>, <Element 'County' at 0x176aaf8b0>, <Element 'County' at 0x176aaf630>, <Element 'County' at 0x176aaf540>, <Element 'County' at 0x176aaf130>, <Element 'County' at 0x176aaf310>, <Element 'County' at 0x176aaf4f0>, <Element 'County' at 0x176aaf770>, <Element 'County' at 0x176aaf950>, <Element 'County' at 0x176aafbd0>, <Element 'County' at 0x176aafdb0>, <Element 'County' at 0x176aafd10>, <Element 'County' at 0x176aaf040>, <Element 'County' at 0x176aaf5e0>, <Element 'County' at 0x176aaf0e0>, <Element 'County' at 0x176aafe50>, <Element 'County' at 0x176aaf9f0>, <Element 'County' at 0x176aaf1d0>, <Element 'County' at 0x176aafb30>, <Element 'County' at 0x176aafc70>, <Element 'County' at 0x176aaf9a0>, <Element 'County' at 0x176a93180>, <Element 'County' at 0x176a93360>, <Element 'County' at 0x176a93860>, <Element 'County' at 0x176a93f40>, <Element 'County' at 0x176a93040>, <Element 'County' at 0x176a93220>, <Element 'County' at 0x176a934a0>, <Element 'County' at 0x176a93680>, <Element 'County' at 0x176a93900>, <Element 'County' at 0x176a93ae0>, <Element 'County' at 0x176a93d60>, <Element 'County' at 0x176a93ea0>, <Element 'County' at 0x176a931d0>, <Element 'County' at 0x176a939a0>, <Element 'County' at 0x176a935e0>, <Element  ...
# [<Element 'County' at 0x1776a4b80>, <Element 'County' at 0x1776a4e00>, <Element 'County' at 0x1776a49f0>, <Element 'County' at 0x1776a4130>, <Element 'County' at 0x1776a44a0>, <Element 'County' at 0x1776a4770>, <Element 'County' at 0x1776a4b30>, <Element 'County' at 0x1776a4db0>, <Element 'County' at 0x1776a4ef0>, <Element 'County' at 0x1776cd9f0>, <Element 'County' at 0x1776cd310>, <Element 'County' at 0x1776cd4f0>, <Element 'County' at 0x1776cd770>, <Element 'County' at 0x1776cd950>, <Element 'County' at 0x1776cdc70>, <Element 'County' at 0x1776cdef0>, <Element 'County' at 0x1776cd7c0>, <Element 'County' at 0x1776cd130>, <Element 'County' at 0x1776cd630>, <Element 'County' at 0x1776cda40>, <Element 'County' at 0x1776cdcc0>, <Element 'County' at 0x1776cd6d0>, <Element 'County' at 0x1776cd090>, <Element 'County' at 0x1776cdb30>, <Element 'County' at 0x1776cdd10>, <Element 'County' at 0x1776cd270>, <Element 'County' at 0x1776d6e00>, <Element 'County' at 0x1776d6040>, <Element 'County' at 0x1776d6270>, <Element 'County' at 0x1776d64f0>, <Element 'County' at 0x1776d6770>, <Element 'County' at 0x1776d6a90>, <Element 'County' at 0x1776d6c70>, <Element 'County' at 0x1776d6ef0>, <Element 'County' at 0x1776d6950>, <Element 'County' at 0x1776d6310>, <Element 'County' at 0x1776d6630>, <Element 'County' at 0x1776d69a0>, <Element 'County' at 0x1776d6bd0>, <Element 'County' at 0x1776d6f90>, <Element 'County' at 0x1776d62c0>, <Element 'County' at 0x1776d67c0>, <Element 'County' at 0x1776d60e0>, <Element 'County' at 0x1776d6e50>, <Element 'County' at 0x1776d8770>, <Element 'County' at 0x1776d8040>, <Element 'County' at 0x1776d82c0>, <Element 'County' at 0x1776d8540>, <Element 'County' at 0x1776d8860>, <Element 'County' at 0x1776d8a40>, <Element 'County' at 0x1776d8cc0>, <Element 'County' at 0x1776d8ea0>, <Element 'County' at 0x1776d8d60>, <Element 'County' at 0x1776d84f0>, <Element 'County' at 0x1776d80e0>, <Element 'County' at 0x1776d8400>, <Element 'County' at 0x1776d8630>, <Element 'County' at 0x1776d88b0>, <Element 'County' at 0x1776d8d10>, <Element 'County' at 0x1776d8810>, <Element 'County' at 0x1776d8f40>, <Element 'County' at 0x1776d8f90>, <Element 'County' at 0x1776f09f0>, <Element 'County' at 0x1776f0220>, <Element 'County' at 0x1776f0400>, <Element 'County' at 0x1776f05e0>, <Element 'County' at 0x1776f07c0>, <Element 'County' at 0x1776f09a0>, <Element 'County' at 0x1776f0b80>, <Element 'County' at 0x1776f0ea0>, <Element 'County' at 0x1776f0590>, <Element 'County' at 0x1776f00e0>, <Element 'County' at 0x1776f0090>, <Element 'County' at 0x1776f04a0>, <Element 'County' at 0x1776f0810>, <Element 'County' at 0x1776f0e50>, <Element 'County' at 0x1776f01d0>, <Element 'County' at 0x1776f0680>, <Element 'County' at 0x1776f0cc0>, <Element 'County' at 0x1776f0f90>, <Element 'County' at 0x1777880e0>, <Element 'County' at 0x177788360>, <Element 'County' at 0x177788540>, <Element 'County' at 0x177788720>, <Element 'County' at 0x177788900>, <Element 'County' at 0x177788ae0>, <Element 'County' at 0x177788cc0>, <Element 'County' at 0x177788ea0>, <Element 'County' at 0x177788d60>, <Element 'County' at 0x1777884f0>, <Element 'County' at 0x1777881d0>, <Element 'County' at 0x1777885e0>, <Element 'County' at 0x1777888b0>, <Element 'County' at 0x177788c20>, <Element 'County' at 0x177788d10>, <Element 'County' at 0x17779a8b0>, <Element 'County' at 0x17779acc0>, <Element 'County' at 0x17779a130>, <Element 'County' at 0x17779a3b0>, <Element 'County' at 0x17779a590>, <Element 'County' at 0x17779a720>, <Element 'County' at 0x17779adb0>, <Element 'County' at 0x17779a310>, <Element 'County' at 0x17779a400>, <Element 'County' at 0x17779a180>, <Element 'County' at 0x17779a6d0>, <Element 'County' at 0x17779a900>, <Element 'County' at 0x17779ab80>, <Element 'County' at 0x17779ae00>, <Element 'County' at 0x177805ef0>, <Element 'County' at 0x1778054f0>, <Element 'County' at 0x177805270>, <Element 'County' at 0x177805450>, <Element 'County' at 0x177805630>, <Element  ...
# ...
# [<Element 'County' at 0x174e3ddb0>, <Element 'County' at 0x174e3dd60>, <Element 'County' at 0x174e3dcc0>, <Element 'County' at 0x174e3dc20>, <Element 'County' at 0x174e3db80>, <Element 'County' at 0x174e3dae0>, <Element 'County' at 0x174e3da40>, <Element 'County' at 0x174e3d9a0>, <Element 'County' at 0x174e3d900>, <Element 'County' at 0x174e3d860>, <Element 'County' at 0x174e3d7c0>, <Element 'County' at 0x174e3d720>, <Element 'County' at 0x174e3d680>, <Element 'County' at 0x174e3d5e0>, <Element 'County' at 0x174e3d540>, <Element 'County' at 0x174e3d4a0>, <Element 'County' at 0x174e3d400>, <Element 'County' at 0x174e3d360>, <Element 'County' at 0x174e3d2c0>, <Element 'County' at 0x174e3d220>, <Element 'County' at 0x174e3d180>, <Element 'County' at 0x174e3d0e0>, <Element 'County' at 0x174e30810>, <Element 'County' at 0x174e30ef0>, <Element 'County' at 0x174e30e50>, <Element 'County' at 0x174e30db0>, <Element 'County' at 0x174e30d10>, <Element 'County' at 0x174e30c70>, <Element 'County' at 0x174e30bd0>, <Element 'County' at 0x174e30b30>, <Element 'County' at 0x174e30a90>, <Element 'County' at 0x174e309f0>, <Element 'County' at 0x174e30950>, <Element 'County' at 0x174e308b0>, <Element 'County' at 0x174e30860>, <Element 'County' at 0x174e306d0>, <Element 'County' at 0x174e30630>, <Element 'County' at 0x174e30590>, <Element 'County' at 0x174e304f0>, <Element 'County' at 0x174e30450>, <Element 'County' at 0x174e303b0>, <Element 'County' at 0x174e30310>, <Element 'County' at 0x174e30270>, <Element 'County' at 0x174e301d0>, <Element 'County' at 0x174e30130>, <Element 'County' at 0x174e30090>, <Element 'County' at 0x174e30040>, <Element 'County' at 0x174e231d0>, <Element 'County' at 0x174e23ef0>, <Element 'County' at 0x174e23e50>, <Element 'County' at 0x174e23db0>, <Element 'County' at 0x174e23d10>, <Element 'County' at 0x174e23c70>, <Element 'County' at 0x174e23bd0>, <Element 'County' at 0x174e23b30>, <Element 'County' at 0x174e23a90>, <Element 'County' at 0x174e239f0>, <Element 'County' at 0x174e23950>, <Element 'County' at 0x174e238b0>, <Element 'County' at 0x174e23810>, <Element 'County' at 0x174e23770>, <Element 'County' at 0x174e236d0>, <Element 'County' at 0x174e23630>, <Element 'County' at 0x174e23590>, <Element 'County' at 0x174e234f0>, <Element 'County' at 0x174e23450>, <Element 'County' at 0x174e233b0>, <Element 'County' at 0x174e23310>, <Element 'County' at 0x174e23270>, <Element 'County' at 0x174e23220>, <Element 'County' at 0x174e23040>, <Element 'County' at 0x174e13ae0>, <Element 'County' at 0x174e13f90>, <Element 'County' at 0x174e13ef0>, <Element 'County' at 0x174e13e50>, <Element 'County' at 0x174e13db0>, <Element 'County' at 0x174e13d10>, <Element 'County' at 0x174e13c70>, <Element 'County' at 0x174e13bd0>, <Element 'County' at 0x174e13a40>, <Element 'County' at 0x174e139f0>, <Element 'County' at 0x174e13950>, <Element 'County' at 0x174e138b0>, <Element 'County' at 0x174e13810>, <Element 'County' at 0x174e13770>, <Element 'County' at 0x174e136d0>, <Element 'County' at 0x174e13630>, <Element 'County' at 0x174e13590>, <Element 'County' at 0x174e134f0>, <Element 'County' at 0x174e13450>, <Element 'County' at 0x174e133b0>, <Element 'County' at 0x174e13310>, <Element 'County' at 0x174e13270>, <Element 'County' at 0x174e131d0>, <Element 'County' at 0x174e13130>, <Element 'County' at 0x174e13090>, <Element 'County' at 0x174e07f40>, <Element 'County' at 0x174e07ea0>, <Element 'County' at 0x174e07e00>, <Element 'County' at 0x174e07d60>, <Element 'County' at 0x174e07cc0>, <Element 'County' at 0x174e07c20>, <Element 'County' at 0x174e07b80>, <Element 'County' at 0x174e07ae0>, <Element 'County' at 0x174e07a40>, <Element 'County' at 0x174e079a0>, <Element 'County' at 0x174e07900>, <Element 'County' at 0x174e07860>, <Element 'County' at 0x174e077c0>, <Element 'County' at 0x174e07720>, <Element 'County' at 0x174e07680>, <Element 'County' at 0x174e075e0>, <Element 'County' at 0x174e07540>, <Element 'County' at 0x174e074f0>, <Element  ...
# [<Element 'County' at 0x174dea540>, <Element 'County' at 0x174dea4a0>, <Element 'County' at 0x174dea400>, <Element 'County' at 0x174dea360>, <Element 'County' at 0x174dea2c0>, <Element 'County' at 0x174dea220>, <Element 'County' at 0x174dea180>, <Element 'County' at 0x174dea0e0>, <Element 'County' at 0x174dea040>, <Element 'County' at 0x174de0130>, <Element 'County' at 0x174de0270>, <Element 'County' at 0x174de01d0>, <Element 'County' at 0x174de0180>, <Element 'County' at 0x174de0040>, <Element 'County' at 0x174de0400>, <Element 'County' at 0x174de0f40>, <Element 'County' at 0x174de0ea0>, <Element 'County' at 0x174de0e00>, <Element 'County' at 0x174de0d60>, <Element 'County' at 0x174de0cc0>, <Element 'County' at 0x174de0c20>, <Element 'County' at 0x174de0b80>, <Element 'County' at 0x174de0ae0>, <Element 'County' at 0x174de0a40>, <Element 'County' at 0x174de09a0>, <Element 'County' at 0x174de0900>, <Element 'County' at 0x174de0860>, <Element 'County' at 0x174de07c0>, <Element 'County' at 0x174de0720>, <Element 'County' at 0x174de0680>, <Element 'County' at 0x174de05e0>, <Element 'County' at 0x174de0540>, <Element 'County' at 0x174de04a0>, <Element 'County' at 0x175308c70>, <Element 'County' at 0x175308ef0>, <Element 'County' at 0x175308e50>, <Element 'County' at 0x175308db0>, <Element 'County' at 0x175308d10>, <Element 'County' at 0x175308cc0>, <Element 'County' at 0x175308b30>, <Element 'County' at 0x175308a90>, <Element 'County' at 0x1753089f0>, <Element 'County' at 0x175308950>, <Element 'County' at 0x1753088b0>, <Element 'County' at 0x175308810>, <Element 'County' at 0x175308770>, <Element 'County' at 0x1753086d0>, <Element 'County' at 0x175308630>, <Element 'County' at 0x175308590>, <Element 'County' at 0x1753084f0>, <Element 'County' at 0x175308450>, <Element 'County' at 0x1753083b0>, <Element 'County' at 0x175308310>, <Element 'County' at 0x175308270>, <Element 'County' at 0x1753081d0>, <Element 'County' at 0x175308130>, <Element 'County' at 0x175308090>, <Element 'County' at 0x175308040>, <Element 'County' at 0x1752baf90>, <Element 'County' at 0x1752baf40>, <Element 'County' at 0x1752baea0>, <Element 'County' at 0x1752bae00>, <Element 'County' at 0x1752bad60>, <Element 'County' at 0x1752bacc0>, <Element 'County' at 0x1752bac20>, <Element 'County' at 0x1752bab80>, <Element 'County' at 0x1752baae0>, <Element 'County' at 0x1752baa40>, <Element 'County' at 0x1752ba9a0>, <Element 'County' at 0x1752ba900>, <Element 'County' at 0x1752ba860>, <Element 'County' at 0x1752ba7c0>, <Element 'County' at 0x1752ba720>, <Element 'County' at 0x1752ba590>, <Element 'County' at 0x1752ba540>, <Element 'County' at 0x1752ba4a0>, <Element 'County' at 0x1752ba400>, <Element 'County' at 0x1752ba360>, <Element 'County' at 0x1752ba2c0>, <Element 'County' at 0x1752ba220>, <Element 'County' at 0x1752ba180>, <Element 'County' at 0x1752ba0e0>, <Element 'County' at 0x1752abf90>, <Element 'County' at 0x1752abe50>, <Element 'County' at 0x1752abdb0>, <Element 'County' at 0x1752abd10>, <Element 'County' at 0x1752abc70>, <Element 'County' at 0x1752abbd0>, <Element 'County' at 0x1752abb30>, <Element 'County' at 0x1752aba90>, <Element 'County' at 0x1752ab9f0>, <Element 'County' at 0x1752ab950>, <Element 'County' at 0x1752ab8b0>, <Element 'County' at 0x1752ab810>, <Element 'County' at 0x1752ab770>, <Element 'County' at 0x1752ab6d0>, <Element 'County' at 0x1752ab630>, <Element 'County' at 0x1752ab590>, <Element 'County' at 0x1752ab4f0>, <Element 'County' at 0x1752ab450>, <Element 'County' at 0x1752ab3b0>, <Element 'County' at 0x1752ab310>, <Element 'County' at 0x1752ab270>, <Element 'County' at 0x1752ab1d0>, <Element 'County' at 0x1752ab130>, <Element 'County' at 0x1752ab090>, <Element 'County' at 0x1752ab040>, <Element 'County' at 0x17529e950>, <Element 'County' at 0x17529eef0>, <Element 'County' at 0x17529ee50>, <Element 'County' at 0x17529edb0>, <Element 'County' at 0x17529ed10>, <Element 'County' at 0x17529ec70>, <Element 'County' at 0x17529ebd0>, <Element  ...
# [<Element 'County' at 0x175282b80>, <Element 'County' at 0x175282b30>, <Element 'County' at 0x175282a90>, <Element 'County' at 0x1752829f0>, <Element 'County' at 0x175282950>, <Element 'County' at 0x1752828b0>, <Element 'County' at 0x175282810>, <Element 'County' at 0x175282770>, <Element 'County' at 0x1752826d0>, <Element 'County' at 0x175282630>, <Element 'County' at 0x175282590>, <Element 'County' at 0x1752824f0>, <Element 'County' at 0x175282450>, <Element 'County' at 0x1752823b0>, <Element 'County' at 0x175282310>, <Element 'County' at 0x175282270>, <Element 'County' at 0x1752821d0>, <Element 'County' at 0x175282130>, <Element 'County' at 0x175282090>, <Element 'County' at 0x175274f40>, <Element 'County' at 0x175274ea0>, <Element 'County' at 0x175274e00>, <Element 'County' at 0x175274d60>, <Element 'County' at 0x175274cc0>, <Element 'County' at 0x175274c20>, <Element 'County' at 0x175274b80>, <Element 'County' at 0x175274ae0>, <Element 'County' at 0x175274a40>, <Element 'County' at 0x1752749a0>, <Element 'County' at 0x175274900>, <Element 'County' at 0x175274860>, <Element 'County' at 0x1752747c0>, <Element 'County' at 0x175274720>, <Element 'County' at 0x175274680>, <Element 'County' at 0x175274630>, <Element 'County' at 0x1752744a0>, <Element 'County' at 0x175274400>, <Element 'County' at 0x175274360>, <Element 'County' at 0x1752742c0>, <Element 'County' at 0x175274220>, <Element 'County' at 0x175274180>, <Element 'County' at 0x1752740e0>, <Element 'County' at 0x175274040>, <Element 'County' at 0x175274090>, <Element 'County' at 0x175264f90>, <Element 'County' at 0x175264e00>, <Element 'County' at 0x175264d60>, <Element 'County' at 0x175264cc0>, <Element 'County' at 0x175264c20>, <Element 'County' at 0x175264b80>, <Element 'County' at 0x175264ae0>, <Element 'County' at 0x175264a40>, <Element 'County' at 0x1752649a0>, <Element 'County' at 0x175264900>, <Element 'County' at 0x175264860>, <Element 'County' at 0x1752647c0>, <Element 'County' at 0x175264720>, <Element 'County' at 0x175264680>, <Element 'County' at 0x1752645e0>, <Element 'County' at 0x175264540>, <Element 'County' at 0x1752644a0>, <Element 'County' at 0x175264400>, <Element 'County' at 0x175264360>, <Element 'County' at 0x1752642c0>, <Element 'County' at 0x175264220>, <Element 'County' at 0x175264180>, <Element 'County' at 0x1752640e0>, <Element 'County' at 0x175264040>, <Element 'County' at 0x17525a720>, <Element 'County' at 0x17525a590>, <Element 'County' at 0x17525a4f0>, <Element 'County' at 0x17525a450>, <Element 'County' at 0x17525a3b0>, <Element 'County' at 0x17525a310>, <Element 'County' at 0x17525a270>, <Element 'County' at 0x17525a1d0>, <Element 'County' at 0x17525a130>, <Element 'County' at 0x17525a090>, <Element 'County' at 0x17525a040>, <Element 'County' at 0x17525ab80>, <Element 'County' at 0x17525af40>, <Element 'County' at 0x17525aea0>, <Element 'County' at 0x17525ae00>, <Element 'County' at 0x17525ad60>, <Element 'County' at 0x17525acc0>, <Element 'County' at 0x17525ac20>, <Element 'County' at 0x17525a7c0>, <Element 'County' at 0x17525a9f0>, <Element 'County' at 0x17525a950>, <Element 'County' at 0x17525a8b0>, <Element 'County' at 0x17525a810>, <Element 'County' at 0x17525a770>, <Element 'County' at 0x173370ea0>, <Element 'County' at 0x173370f90>, <Element 'County' at 0x173370e00>, <Element 'County' at 0x173370db0>, <Element 'County' at 0x173370d10>, <Element 'County' at 0x173370c70>, <Element 'County' at 0x173370bd0>, <Element 'County' at 0x173370b30>, <Element 'County' at 0x173370a90>, <Element 'County' at 0x1733709f0>, <Element 'County' at 0x173370950>, <Element 'County' at 0x1733708b0>, <Element 'County' at 0x173370810>, <Element 'County' at 0x173370770>, <Element 'County' at 0x1733706d0>, <Element 'County' at 0x173370630>, <Element 'County' at 0x173370590>, <Element 'County' at 0x1733704f0>, <Element 'County' at 0x173370450>, <Element 'County' at 0x1733703b0>, <Element 'County' at 0x173370310>, <Element 'County' at 0x173370270>, <Element  ...
# detailxml (9).zip
# detailxml (8).zip
# detailxml (7).zip

# %%
df_general.drop(["state","file"], inplace = True, axis = 1)

# %%
races_list = ['US House District 1',
       'US House District 2', 'US House District 3',
       'US House District 4', 'US House District 5',
       'US House District 6', 'US House District 7',
       'US House District 8', 'US House District 9',
       'US House District 10', 'US House District 11',
       'US House District 12', 'US House District 13',
       'US House District 14', 'State Senate District 1',
       'State Senate District 2', 'State Senate District 3',
       'State Senate District 4',
       'State Senate Dist 5/Senador Estatal Dist 5',
       'State Senate District 6', 'State Senate District 7',
       'State Senate District 8',
       'State Senate Dist 9/Senador Estatal Dist 9',
       'State Senate District 10', 'State Senate District 11',
       'State Senate District 12', 'State Senate District 13',
       'State Senate District 14', 'State Senate District 15',
       'State Senate District 16', 'State Senate District 17',
       'State Senate District 18', 'State Senate District 19',
       'State Senate District 20', 'State Senate District 21',
       'State Senate District 22', 'State Senate District 23',
       'State Senate District 24', 'State Senate District 25',
       'State Senate District 26', 'State Senate District 27',
       'State Senate District 28', 'State Senate District 29',
       'State Senate District 30', 'State Senate District 31',
       'State Senate District 32', 'State Senate District 33',
       'State Senate District 34', 'State Senate District 35',
       'State Senate District 36', 'State Senate District 37',
       'State Senate District 38',
       'State Senate District 39 - Special Democratic Primary',
       'State Senate District 40', 'State Senate District 41',
       'State Senate District 42', 'State Senate District 43',
       'State Senate District 44',
       'State Senate Dist 45/Senador Estatal Dist 45',
       'State Senate District 46', 'State Senate District 47',
       'State Senate District 48', 'State Senate District 49',
       'State Senate District 50', 'State Senate District 51',
       'State Senate District 52', 'State Senate District 53',
       'State Senate District 54', 'State Senate District 55',
       'State Senate District 56', 'State House District 1',
       'State House District 2', 'State House District 3',
       'State House District 4', 'State House District 5',
       'State House District 6', 'State House District 7',
       'State House District 8', 'State House District 9',
       'State House District 10', 'State House District 11',
       'State House District 12', 'State House District 13',
       'State House District 14', 'State House District 15',
       'State House District 16', 'State House District 17',
       'State House District 18', 'State House District 19',
       'State House District 20', 'State House District 21',
       'State House District 22', 'State House District 23',
       'State House District 24', 'State House District 25',
       'State House District 26', 'State House District 27',
       'State House District 28', 'State House District 29',
       'State House District 30', 'State House District 31',
       'State House District 32', 'State House District 33',
       'State House District 34', 'State House District 35',
       'State House District 36', 'State House District 37',
       'State House District 38', 'State House District 39',
       'State House District 40', 'State House District 41',
       'State House District 42', 'State House District 43',
       'State House District 44', 'State House District 45',
       'State House District 46', 'State House District 47',
       'State House District 48', 'State House District 49',
       'State House District 50', 'State House District 51',
       'State House District 52', 'State House District 53',
       'State House District 54', 'State House District 55',
       'State House District 56', 'State House District 57',
       'State House District 58', 'State House District 59',
       'State House District 60', 'State House District 61',
       'State House District 62', 'State House District 63',
       'State House District 64', 'State House District 65',
       'State House District 66', 'State House District 67',
       'State House District 68', 'State House District 69',
       'State House District 70', 'State House District 71',
       'State House District 72', 'State House District 73',
       'State House District 74', 'State House District 75',
       'State House District 76', 'State House District 77',
       'State House District 78', 'State House District 79',
       'State House District 80', 'State House District 81',
       'State House District 82', 'State House District 83',
       'State House District 84', 'State House District 85',
       'State House District 86', 'State House District 87',
       'State House District 88', 'State House District 89',
       'State House District 90', 'State House District 91',
       'State House District 92', 'State House District 93',
       'State House District 94', 'State House District 95',
       'State House Dist 96/Estatal ante la Asamblea General Dist 96',
       'State House Dist 97/Estatal ante la Asamblea General Dist 97',
       'State House Dist 98/Estatal ante la Asamblea General Dist 98',
       'State House Dist 99/Estatal ante la Asamblea General Dist 99',
       'State House Dist 100/Estatal ante la Asamblea General Dist 100',
       'State House Dist 101/Estatal ante la Asamblea General Dist 101',
       'State House Dist 102/Estatal ante la Asamblea General Dist 102',
       'State House Dist 103/Estatal ante la Asamblea General Dist 103',
       'State House Dist 104/Estatal ante la Asamblea General Dist 104',
       'State House Dist 105/Estatal ante la Asamblea General Dist 105',
       'State House Dist 106/Estatal ante la Asamblea General Dist 106',
       'State House Dist 107/Estatal ante la Asamblea General Dist 107',
       'State House Dist 108/Estatal ante la Asamblea General Dist 108',
       'State House District 109', 'State House District 110',
       'State House District 111', 'State House District 112',
       'State House District 113', 'State House District 114',
       'State House District 115', 'State House District 116',
       'State House District 117', 'State House District 118',
       'State House District 119', 'State House District 120',
       'State House District 121', 'State House District 122',
       'State House District 123', 'State House District 124',
       'State House District 125', 'State House District 126',
       'State House District 127', 'State House District 128',
       'State House District 129', 'State House District 130',
       'State House District 131', 'State House District 132',
       'State House District 133', 'State House District 134',
       'State House District 135', 'State House District 136',
       'State House District 137', 'State House District 138',
       'State House District 139', 'State House District 140',
       'State House District 141', 'State House District 142',
       'State House District 143', 'State House District 144',
       'State House District 145', 'State House District 146',
       'State House District 147', 'State House District 148',
       'State House District 149', 'State House District 150',
       'State House District 151', 'State House District 152',
       'State House District 153', 'State House District 154',
       'State House District 155', 'State House District 156',
       'State House District 157', 'State House District 158',
       'State House District 159', 'State House District 160',
       'State House District 161', 'State House District 162',
       'State House District 163', 'State House District 164',
       'State House District 165', 'State House District 166',
       'State House District 167', 'State House District 168',
       'State House District 169', 'State House District 170',
       'State House District 171', 'State House District 172',
       'State House District 173', 'State House District 174',
       'State House District 175', 'State House District 176',
       'State House District 177', 'State House District 178',
       'State House District 179', 'State House District 180','Constitutional Amendment #1', 'Constitutional Amendment #2',
       'Statewide Referendum A']

# %%
df_general = df_general[df_general["contest"].isin(races_list)]

# %%
df_general
# Out:
#                       contest                              choice  \
# 20352     US House District 1  Earl L. ""Buddy"" Carter (I) (Rep)
# 20353     US House District 1  Earl L. ""Buddy"" Carter (I) (Rep)
# 20354     US House District 1  Earl L. ""Buddy"" Carter (I) (Rep)
# 20355     US House District 1  Earl L. ""Buddy"" Carter (I) (Rep)
# 20356     US House District 1  Earl L. ""Buddy"" Carter (I) (Rep)
# ...                       ...                                 ...
# 29815  Statewide Referendum A                                  NO
# 29816  Statewide Referendum A                                  NO
# 29817  Statewide Referendum A                                  NO
# 29818  Statewide Referendum A                                  NO
# 29819  Statewide Referendum A                                  NO
#
#             voting_method     county num_votes
# 20352  Election Day Votes      Bacon       418
# 20353  Election Day Votes   Brantley      1903
# 20354  Election Day Votes      Bryan      2635
# 20355  Election Day Votes     Camden      3561
# 20356  Election Day Votes   Charlton      1091
# ...                   ...        ...       ...
# 29815   Provisional Votes  Whitfield        19
# 29816   Provisional Votes     Wilcox         0
# 29817   Provisional Votes     Wilkes         2
# 29818   Provisional Votes  Wilkinson         2
# 29819   Provisional Votes      Worth         0
#
# [8884 rows x 5 columns]

# %%
fields_dict = {}
for val in os.listdir("./cand_dicts/"):
    holder = pd.read_csv("./cand_dicts/"+val)
    holder_dict = dict(zip(holder["Cand_Name"], holder["Field_Name"]))
    print(len(holder_dict))
    fields_dict.update(holder_dict)
# Out:
# 87
# 38
# 28
# 267

# %%
fields_dict
# Out:
# {'Ben Watson (I) (Rep)': 'GSU01RWAT',
#  'Lester G. Jackson, III (I) (Dem)': 'GSU02DJAC',
#  'Sheila McNeill (Rep)': 'GSU03RMCN',
#  'Billy Hickman (I) (Rep)': 'GSU04RHIC',
#  'Sheikh Rahman (I) (Dem)': 'GSU05DRAH',
#  'Jennifer ""Jen"" Jordan (I) (Dem)': 'GSU06DJOR',
#  'Harrison Lance (Rep)': 'GSU06RLAN',
#  'Tyler Harper (I) (Rep)': 'GSU07RHAR',
#  'Treva Gear (Dem)': 'GSU08DGEA',
#  'Russ Goodman (Rep)': 'GSU08RGOO',
#  'Nikki Merritt (Dem)': 'GSU09DMER',
#  'P. K. Martin, IV (I) (Rep)': 'GSU09RMAR',
#  'Emanuel Jones (I) (Dem)': 'GSU10DJON',
#  'Dean Burke (I) (Rep)': 'GSU11RBUR',
#  'Freddie Powell Sims (I) (Dem)': 'GSU12DSIM',
#  'Tracy Taylor (Rep)': 'GSU12RTAY',
#  'Mary Egler (Dem)': 'GSU13DEGL',
#  'Carden H. Summers (I) (Rep)': 'GSU13RSUM',
#  'Travis Johnson (Dem)': 'GSU14DJOH',
#  'Bruce Thompson (I) (Rep)': 'GSU14RTHO',
#  'Ed Harbison (I) (Dem)': 'GSU15DHAR',
#  'Cinquez Jester (Dem)': 'GSU16DJES',
#  'Marty Harbin (I) (Rep)': 'GSU16RHAR',
#  'Kelly Rose (Dem)': 'GSU17DROS',
#  'Brian Strickland (I) (Rep)': 'GSU17RSTR',
#  'John F. Kennedy (I) (Rep)': 'GSU18RKEN',
#  'Blake Tillery (I) (Rep)': 'GSU19RTIL',
#  'Julius Newberry Johnson (Dem)': 'GSU20DJOH',
#  'Larry Walker (I) (Rep)': 'GSU20RWAL',
#  'Brandon Beach (I) (Rep)': 'GSU21RBEA',
#  'Harold V. Jones, II (I) (Dem)': 'GSU22DJON',
#  'Ceretta Smith (Dem)': 'GSU23DSMI',
#  'Max Burns (Rep)': 'GSU23RBUR',
#  'Lee Anderson (I) (Rep)': 'GSU24RAND',
#  'Veronica Brinson (Dem)': 'GSU25DBRI',
#  'Burt Jones (I) (Rep)': 'GSU25RJON',
#  'David E. Lucas, Sr. (I) (Dem)': 'GSU26DLUC',
#  'Brooke Griffiths (Dem)': 'GSU27DGRI',
#  'Greg Dolezal (I) (Rep)': 'GSU27RDOL',
#  'Matt Brass (I) (Rep)': 'GSU28RBRA',
#  'Randy Robertson (I) (Rep)': 'GSU29RROB',
#  'Montenia Edwards (Dem)': 'GSU30DEDW',
#  'Mike Dugan (I) (Rep)': 'GSU30RDUG',
#  'Tianna Smith (Dem)': 'GSU31DSMI',
#  'Jason Anavitarte (Rep)': 'GSU31RANA',
#  'Christine Triebsch (Dem)': 'GSU32DTRI',
#  'Kay Kirkpatrick (I) (Rep)': 'GSU32RKIR',
#  'Michael Rhett (I) (Dem)': 'GSU33DRHE',
#  'Valencia M. Seay (I) (Dem)': 'GSU34DSEA',
#  'Donzella James (I) (Dem)': 'GSU35DJAM',
#  'Nan Orrock (I) (Dem)': 'GSU36DORR',
#  'Vanessa Parker (Dem)': 'GSU37DPAR',
#  'Lindsey Tippins (I) (Rep)': 'GSU37RTIP',
#  'Horacena Tate (I) (Dem)': 'GSU38DTAT',
#  'Sally Harrell (I) (Dem)': 'GSU40DHAR',
#  'Garry Guan (Rep)': 'GSU40RGUA',
#  'Kim Jackson (Dem)': 'GSU41DJAC',
#  'William Park Freeman (Rep)': 'GSU41RFRE',
#  'Elena Parent (I) (Dem)': 'GSU42DPAR',
#  'Tonya P. Anderson (I) (Dem)': 'GSU43DAND',
#  'Melanie Williams (Rep)': 'GSU43RWIL',
#  'Gail Davenport (I) (Dem)': 'GSU44DDAV',
#  'Benjamin Brooks (Rep)': 'GSU44RBRO',
#  'Matielyn Jones (Dem)': 'GSU45DJON',
#  'Clint Dixon (Rep)': 'GSU45RDIX',
#  'Zachary Perry (Dem)': 'GSU46DPER',
#  'Bill Cowsert (I) (Rep)': 'GSU46RCOW',
#  'Dawn Johnson (Dem)': 'GSU47DJOH',
#  'Frank Ginn (I) (Rep)': 'GSU47RGIN',
#  'Michelle Au (Dem)': 'GSU48DAU',
#  'Matt Reeves (Rep)': 'GSU48RREE',
#  'Cecil T. ""Butch"" Miller (I) (Rep)': 'GSU49RMIL',
#  'Dee Daley (Dem)': 'GSU50DDAL',
#  'Bo Hatchett (Rep)': 'GSU50RHAT',
#  'June Krise (Dem)': 'GSU51DKRI',
#  'Steve Gooch (I) (Rep)': 'GSU51RGOO',
#  'Charles DeYoung (Dem)': 'GSU52DDEY',
#  'Chuck Hufstetler (I) (Rep)': 'GSU52RHUF',
#  'Jeff Mullis (I) (Rep)': 'GSU53RMUL',
#  'Chuck Payne (I) (Rep)': 'GSU54RPAY',
#  'Gloria S. Butler (I) (Dem)': 'GSU55DBUT',
#  'Sarah Beeson (Dem)': 'GSU56DBEE',
#  'John Albers (I) (Rep)': 'GSU56RALB',
#  'Zan Fort': 'PSU39DFOR',
#  'Sonya Halpern': 'PSU39DHAL',
#  'Jo Anna Potts': 'PSU39DPOT',
#  'Linda Pritchett': 'PSU39DPRI',
#  'Donald J. Trump (Republican Party)': 'C20PRERTRU',
#  'Joseph R. Biden (Democratic Party)': 'C20PREDBID',
#  'Jo Jorgensen (Libertarian Party)': 'C20PRELJOR',
#  'David A. Perdue (Republican Party)': 'R21USSRPER',
#  'Jon Ossoff (Democratic Party)': 'R21USSDOSS',
#  'Shane Hazel (Libertarian Party)': 'G20USSLHAZ',
#  'Kelly Loeffler (Republican Party)': 'R21USSRLOE',
#  'Doug Collins (Republican Party)': 'S20USSRCOL',
#  'Derrick E. Grayson (Republican Party)': 'S20USSRGRA',
#  'Annette Davis Jackson (Republican Party)': 'S20USSRJAC',
#  'Kandiss Taylor (Republican Party)': 'S20USSRTAY',
#  'A. Wayne Johnson (Republican Party)': 'S20USSRJOH',
#  'Raphael Warnock (Democratic Party)': 'R21USSDWAR',
#  'Deborah Jackson (Democratic Party)': 'S20USSDJAC',
#  'Matt Lieberman (Democratic Party)': 'S20USSDLIE',
#  'Tamara Johnson-Shealey (Democratic Party)': 'S20USSDJOH',
#  'Jamesia James (Democratic Party)': 'S20USSDJAM',
#  'Joy Felicia Slade (Democratic Party)': 'S20USSDSLA',
#  'Richard Dien Winfield (Democratic Party)': 'S20USSDWIN',
#  'Ed Tarver (Democratic Party)': 'S20USSDTAR',
#  'Brian Slowinski (Libertarian Party)': 'S20USSLSLO',
#  'John Fortuin (Green Party)': 'S20USSGFOR',
#  'Allen Buckley (Independent)': 'S20USSIBUC',
#  'Al Bartell (Independent)': 'S20USSIBAR',
#  'Valencia Stovall (Independent)': 'S20USSISTO',
#  'Michael Todd Greene (Independent)': 'S20USSIGRE',
#  'Jason Shaw (Republican Party)': 'G20PSCRSHA',
#  'Robert G. Bryant (Democratic Party)': 'G20PSCDBRY',
#  'Elizabeth Melton (Libertarian Party)': 'G20PSCLMEL',
#  'Lauren Bubba McDonald, Jr. (Republican Party)': 'R21PSCRMCD',
#  'Daniel Blackman (Democratic Party)': 'P21PSCDBLA',
#  'Nathan Wilson (Libertarian Party)': 'G20PSCLWIL',
#  'Amendment #1 "Yes"': 'G20A01YES',
#  'Amendment #1 "No"': 'G20A01NO',
#  'Amendment #2 "Yes"': 'G20A02YES',
#  'Amendment #2 "No"': 'G20A02NO',
#  'Referendum A "Yes"': 'G20RFAYES',
#  'Referendum A "No"': 'G20RFANO',
#  'Joyce Marie Griggs (Dem)': 'GCON01DGRI',
#  'Earl L. ""Buddy"" Carter (I) (Rep)': 'GCON01RCAR',
#  'Sanford Bishop (I) (Dem)': 'GCON02DBIS',
#  'Don Cole (Rep)': 'GCON02RCOL',
#  'Val Almonord (Dem)': 'GCON03DALM',
#  'Drew Ferguson (I) (Rep)': 'GCON03RFER',
#  'Henry C. ""Hank"" Johnson, Jr. (I) (Dem)': 'GCON04DJOH',
#  'Johsie Cruz Ezammudeen (Rep)': 'GCON04REZA',
#  'Nikema Williams (Dem)': 'GCON05DWIL',
#  'Angela Stanton-King (Rep)': 'GCON05RSTA',
#  'Lucy McBath (I) (Dem)': 'GCON06DMCB',
#  'Karen Handel (Rep)': 'GCON06RHAN',
#  'Carolyn Bourdeaux (Dem)': 'GCON07DBOU',
#  'Rich McCormick (Rep)': 'GCON07RMCC',
#  'Lindsay Holliday (Dem)': 'GCON08DHOL',
#  'Austin Scott (I) (Rep)': 'GCON08RSCO',
#  'Devin Pandy (Dem)': 'GCON09DPAN',
#  'Andrew Clyde (Rep)': 'GCON09RCLY',
#  'Tabitha Johnson-Green (Dem)': 'GCON10DJOH',
#  'Jody Hice (I) (Rep)': 'GCON10RHIC',
#  'Dana Barrett (Dem)': 'GCON11DBAR',
#  'Barry Loudermilk (I) (Rep)': 'GCON11RLOU',
#  'Liz Johnson (Dem)': 'GCON12DJOH',
#  'Rick W. Allen (I) (Rep)': 'GCON12RALL',
#  'David Scott (I) (Dem)': 'GCON13DSCO',
#  'Becky E. Hites (Rep)': 'GCON13RHIT',
#  'Kevin Van Ausdal (Dem)': 'GCON14DAUS',
#  'Marjorie Taylor Greene (Rep)': 'GCON14RGRE',
#  'Mike Cameron (Rep)': 'GSL001RCAM',
#  'Steve Tarvin (I) (Rep)': 'GSL002RTAR',
#  'Dewayne Hill (I) (Rep)': 'GSL003RHIL',
#  'Kasey Carpenter (I) (Rep)': 'GSL004RCAR',
#  'Matt Barton (I) (Rep)': 'GSL005RBAR',
#  'Jason T. Ridley (I) (Rep)': 'GSL006RRID',
#  'Rick D. Day (Dem)': 'GSL007DDAY',
#  'David Ralston (I) (Rep)': 'GSL007RRAL',
#  'Dave Cooper (Dem)': 'GSL008DCOO',
#  'Stan Gunter (Rep)': 'GSL008RGUN',
#  'Sharon L. Ravert (Dem)': 'GSL009DRAV',
#  'Will Wade (Rep)': 'GSL009RWAD',
#  'Nick Mitchell (Dem)': 'GSL010DMIT',
#  'Victor E. Anderson (Rep)': 'GSL010RAND',
#  'Kayla Hollifield (Dem)': 'GSL011DHOL',
#  'Rick Jasperse (I) (Rep)': 'GSL011RJAS',
#  'Jonathan Gilreath-Harvey (Dem)': 'GSL012DGIL',
#  'Eddie Lumsden (I) (Rep)': 'GSL012RLUM',
#  'Katie Dempsey (I) (Rep)': 'GSL013RDEM',
#  'Mitchell Scoggins (I) (Rep)': 'GSL014RSCO',
#  'Matthew Gambill (I) (Rep)': 'GSL015RGAM',
#  'Lyndsay Arrendale (Dem)': 'GSL016DARR',
#  'Trey Kelley (I) (Rep)': 'GSL016RKEL',
#  'Q. Dailey (Dem)': 'GSL017DDAI',
#  'Martin Momtahan (I) (Rep)': 'GSL017RMOM',
#  'Pat Rhudy (Dem)': 'GSL018DRHU',
#  'Tyler Paul Smith (Rep)': 'GSL018RSMI',
#  'Alison Feliciano (Dem)': 'GSL019DFEL',
#  'Joseph Gullett (I) (Rep)': 'GSL019RGUL',
#  'Ginny Lennox (Dem)': 'GSL020DLEN',
#  'Charlice Byrd (Rep)': 'GSL020RBYR',
#  'William D. Hughes (Dem)': 'GSL021DHUG',
#  'Brad Thomas (Rep)': 'GSL021RTHO',
#  'Charles Ravenscraft (Dem)': 'GSL022DRAV',
#  'Wes Cantrell (I) (Rep)': 'GSL022RCAN',
#  'Mandi L. Ballinger (I) (Rep)': 'GSL023RBAL',
#  'Natalie Bucsko (Dem)': 'GSL024DBUC',
#  'Sheri Smallwood Gilligan (I) (Rep)': 'GSL024RGIL',
#  'Christa Olenczak (Dem)': 'GSL025DOLE',
#  'Todd Jones (I) (Rep)': 'GSL025RJON',
#  'Jason Boskey (Dem)': 'GSL026DBOS',
#  'Lauren W. McDonald, III (Rep)': 'GSL026RMCD',
#  'Lee Hawkins (I) (Rep)': 'GSL027RHAW',
#  'Chris Erwin (I) (Rep)': 'GSL028RERW',
#  'Pat Calmes (Dem)': 'GSL029DCAL',
#  'Matt Dubnik (I) (Rep)': 'GSL029RDUB',
#  'Leigh Miller (Dem)': 'GSL030DMIL',
#  'Emory Dunahoo, Jr. (I) (Rep)': 'GSL030RDUN',
#  'Pete Fuller (Dem)': 'GSL031DFUL',
#  'Tommy Benton (I) (Rep)': 'GSL031RBEN',
#  'Alisha Allen (Dem)': 'GSL032DALL',
#  'Alan Powell (I) (Rep)': 'GSL032RPOW',
#  'Kerry Dornell Hamm (Dem)': 'GSL033DHAM',
#  'Rob Leverett (Rep)': 'GSL033RLEV',
#  'Priscilla G. Smith (Dem)': 'GSL034DSMI',
#  'Bert Reeves (I) (Rep)': 'GSL034RREE',
#  'Kyle Rinaudo (Dem)': 'GSL035DRIN',
#  'Ed Setzler (I) (Rep)': 'GSL035RSET',
#  'James Francis Ryner (Dem)': 'GSL036DRYN',
#  'Ginny Ehrhart (I) (Rep)': 'GSL036REHR',
#  'Mary Frances Williams (I) (Dem)': 'GSL037DWIL',
#  'Rose Wing (Rep)': 'GSL037RWIN',
#  'David Wilkerson (I) (Dem)': 'GSL038DWIL',
#  'Erica Thomas (I) (Dem)': 'GSL039DTHO',
#  'Jim Hickey (Rep)': 'GSL039RHIC',
#  'Erick Eugene Allen (I) (Dem)': 'GSL040DALL',
#  'Taryn Chilivis Bowman (Rep)': 'GSL040RBOW',
#  'Michael Smith (I) (Dem)': 'GSL041DSMI',
#  'Stephen M. George, Jr. (Rep)': 'GSL041RGEO',
#  'Teri Anulewicz (I) (Dem)': 'GSL042DANU',
#  'Luisa Wakeman (Dem)': 'GSL043DWAK',
#  'Sharon Cooper (I) (Rep)': 'GSL043RCOO',
#  'Connie DiCicco (Dem)': 'GSL044DDIC',
#  'Don L. Parsons (I) (Rep)': 'GSL044RPAR',
#  'Sara Tindall Ghazal (Dem)': 'GSL045DGHA',
#  'Matt Dollar (I) (Rep)': 'GSL045RDOL',
#  'Caroline L. Holko (Dem)': 'GSL046DHOL',
#  'John Carson (I) (Rep)': 'GSL046RCAR',
#  'Anthia Owens Carter (Dem)': 'GSL047DCAR',
#  'Jan Jones (I) (Rep)': 'GSL047RJON',
#  'Mary Robichaux (I) (Dem)': 'GSL048DROB',
#  'Betty Price (Rep)': 'GSL048RPRI',
#  'Jason T. Hayes (Dem)': 'GSL049DHAY',
#  'Charles E. ""Chuck"" Martin (I) (Rep)': 'GSL049RMAR',
#  'Angelika Kausche (I) (Dem)': 'GSL050DKAU',
#  'Jay Lin (Rep)': 'GSL050RLIN',
#  'Josh McLaurin (I) (Dem)': 'GSL051DMCL',
#  'Alex B. Kaufman (Rep)': 'GSL051RKAU',
#  'Shea Roberts (Dem)': 'GSL052DROB',
#  'Deborah Silcox (I) (Rep)': 'GSL052RSIL',
#  'Sheila Jones (I) (Dem)': 'GSL053DJON',
#  'Betsy Holland (I) (Dem)': 'GSL054DHOL',
#  'Lyndsey Rudder (Rep)': 'GSL054RRUD',
#  'Marie Metze (I) (Dem)': 'GSL055DMET',
#  'Mesha Mainor (Dem)': 'GSL056DMAI',
#  'Stacey Evans (Dem)': 'GSL057DEVA',
#  'Park Cannon (I) (Dem)': 'GSL058DCAN',
#  'David Dreyer (I) (Dem)': 'GSL059DDRE',
#  'Kim Schofield (I) (Dem)': 'GSL060DSCH',
#  'Roger Bruce (I) (Dem)': 'GSL061DBRU',
#  'William K. Boddie, Jr. (I) (Dem)': 'GSL062DBOD',
#  'Debra Bazemore (I) (Dem)': 'GSL063DBAZ',
#  'David Callahan (Rep)': 'GSL063RCAL',
#  'Derrick L. Jackson (I) (Dem)': 'GSL064DJAC',
#  'Mandisha A. Thomas (Dem)': 'GSL065DTHO',
#  'Kimberly Alexander (I) (Dem)': 'GSL066DALE',
#  'Jason C. Jones (Rep)': 'GSL066RJON',
#  'Angela Mayfield (Dem)': 'GSL067DMAY',
#  'Micah Gravley (I) (Rep)': 'GSL067RGRA',
#  'J. Collins (I) (Rep)': 'GSL068RCOL',
#  'Herbert Giles (Dem)': 'GSL069DGIL',
#  'Randy Nix (I) (Rep)': 'GSL069RNIX',
#  'Lynn Smith (I) (Rep)': 'GSL070RSMI',
#  'Jill Prouty (Dem)': 'GSL071DPRO',
#  'Philip Singleton (I) (Rep)': 'GSL071RSIN',
#  'Fred Rovner (Dem)': 'GSL072DROV',
#  'Josh Bonner (I) (Rep)': 'GSL072RBON',
#  'William Harris (Dem)': 'GSL073DHAR',
#  'Karen Mathiak (I) (Rep)': 'GSL073RMAT',
#  'Yasmin Neal (Dem)': 'GSL074DNEA',
#  'Mike Glanton (I) (Dem)': 'GSL075DGLA',
#  'Sandra Givens Scott (I) (Dem)': 'GSL076DSCO',
#  'Rhonda Burnough (I) (Dem)': 'GSL077DBUR',
#  'Demetrius Douglas (I) (Dem)': 'GSL078DDOU',
#  'Michael S. Wilensky (I) (Dem)': 'GSL079DWIL',
#  'Andrea Johnson (Rep)': 'GSL079RJOH',
#  'Matthew Wilson (I) (Dem)': 'GSL080DWIL',
#  'Alan Cole (Rep)': 'GSL080RCOL',
#  'Scott Holcomb (I) (Dem)': 'GSL081DHOL',
#  'Mary Margaret Oliver (I) (Dem)': 'GSL082DOLI',
#  'Becky Evans (I) (Dem)': 'GSL083DEVA',
#  'Renitta Shannon (I) (Dem)': 'GSL084DSHA',
#  'Karla Drenner (I) (Dem)': 'GSL085DDRE',
#  'Zulma Lopez (Dem)': 'GSL086DLOP',
#  'Viola Davis (I) (Dem)': 'GSL087DDAV',
#  'Billy Mitchell (I) (Dem)': 'GSL088DMIT',
#  'Bee Nguyen (I) (Dem)': 'GSL089DNGU',
#  'Pam Stephenson (I) (Dem)': 'GSL090DSTE',
#  'Rhonda S. Taylor (Dem)': 'GSL091DTAY',
#  'Doreen Carter (I) (Dem)': 'GSL092DCAR',
#  "Dar'Shun Kendrick (I) (Dem)": 'GSL093DKEN',
#  'Hubert Owens, Jr. (Rep)': 'GSL093ROWE',
#  'Karen Bennett (I) (Dem)': 'GSL094DBEN',
#  'Beth Moore (I) (Dem)': 'GSL095DMOO',
#  'Erica McCurdy (Rep)': 'GSL095RMCC',
#  'Pedro ""Pete"" Marin (I) (Dem)': 'GSL096DMAR',
#  'Mary Blackmon Campbell (Dem)': 'GSL097DCAM',
#  'Bonnie Rich (I) (Rep)': 'GSL097RRIC',
#  'Taeho Cho (Dem)': 'GSL098DCHO',
#  'David Clark (I) (Rep)': 'GSL098RCLA',
#  'Marvin Lim (Dem)': 'GSL099DLIM',
#  'Dewey L. McClain (I) (Dem)': 'GSL100DMCC',
#  'Sam Park (I) (Dem)': 'GSL101DPAR',
#  'Carol Field (Rep)': 'GSL101RFIE',
#  'Gregg Kennard (I) (Dem)': 'GSL102DKEN',
#  'Soo Hong (Rep)': 'GSL102RHON',
#  'Clifton  Marshall (Dem)': 'GSL103DMAR',
#  'Timothy Barr (I) (Rep)': 'GSL103RBAR',
#  'Nakita Hemingway (Dem)': 'GSL104DHEM',
#  'Chuck Efstration (I) (Rep)': 'GSL104REFS',
#  'Donna McLeod (I) (Dem)': 'GSL105DMCL',
#  'Eric Dierks (Rep)': 'GSL105RDIE',
#  'Rebecca Mitchell (Dem)': 'GSL106DMIT',
#  'Brett Harrell (I) (Rep)': 'GSL106RHAR',
#  'Shelly Hutchinson (I) (Dem)': 'GSL107DHUT',
#  'Michael McConnell (Rep)': 'GSL107RMCC',
#  'Jasmine Clark (I) (Dem)': 'GSL108DCLA',
#  'Johnny Crist (Rep)': 'GSL108RCRI',
#  'Regina Lewis-Ward (Dem)': 'GSL109DLEW',
#  'Dale Rutledge (I) (Rep)': 'GSL109RRUT',
#  'Ebony Carter (Dem)': 'GSL110DCAR',
#  'Clint Crowe (Rep)': 'GSL110RCRO',
#  'El-Mahdi Holly (I) (Dem)': 'GSL111DHOL',
#  'Dave Belton (I) (Rep)': 'GSL112RBEL',
#  'Sharon Henderson (Dem)': 'GSL113DHEN',
#  'Tom Kirby (I) (Rep)': 'GSL114RKIR',
#  'Debbie Reed (Dem)': 'GSL115DREE',
#  'Bruce Williamson (I) (Rep)': 'GSL115RWIL',
#  'Terry England (I) (Rep)': 'GSL116RENG',
#  '""Mokah"" Jasmine Johnson (Dem)': 'GSL117DJOH',
#  'Houston Gaines (I) (Rep)': 'GSL117RGAI',
#  'Spencer Frye (I) (Dem)': 'GSL118DFRY',
#  'Jonathan Wallace (Dem)': 'GSL119DWAL',
#  'Marcus A. Wiedower (I) (Rep)': 'GSL119RWIE',
#  'Trey Rhodes (I) (Rep)': 'GSL120RRHO',
#  'Barry Fleming (I) (Rep)': 'GSL121RFLE',
#  'Doris O. Crutchfield (Dem)': 'GSL122DCRU',
#  'Jodi Lott (I) (Rep)': 'GSL122RLOT',
#  'Mark Newton (I) (Rep)': 'GSL123RNEW',
#  'Henry ""Wayne"" Howard (I) (Dem)': 'GSL124DHOW',
#  'Sheila Clark Nelson (I) (Dem)': 'GSL125DNEL',
#  'Gloria Frazier (I) (Dem)': 'GSL126DFRA',
#  'Brian L. Prince (I) (Dem)': 'GSL127DPRI',
#  'Mack Jackson (I) (Dem)': 'GSL128DJAC',
#  'Sharonda Bell (Dem)': 'GSL129DBEL',
#  'Joe Reed (Ind)': 'GSL129IREE',
#  'Susan Holmes (I) (Rep)': 'GSL129RHOL',
#  'Sheila Henley (Dem)': 'GSL130DHEN',
#  'David Knight (I) (Rep)': 'GSL130RKNI',
#  'Chris Benton (Dem)': 'GSL131DBEN',
#  'Beth Camp (Rep)': 'GSL131RCAM',
#  'Bob Trammell, Jr. (I) (Dem)': 'GSL132DTRA',
#  'David Jenkins (Rep)': 'GSL132RJEN',
#  'Vance Smith, Jr. (I) (Rep)': 'GSL133RSMI',
#  'Carl Sprayberry (Dem)': 'GSL134DSPR',
#  'Richard H. Smith (I) (Rep)': 'GSL134RSMI',
#  'Calvin Smyre (I) (Dem)': 'GSL135DSMY',
#  'Carolyn Hugley (I) (Dem)': 'GSL136DHUG',
#  'Debbie G. Buckner (I) (Dem)': 'GSL137DBUC',
#  'Marc Arnett (Dem)': 'GSL138DARN',
#  'Mike Cheokas (I) (Rep)': 'GSL138RCHE',
#  'Patty Bentley (I) (Dem)': 'GSL139DBEN',
#  'Robert Dickey (I) (Rep)': 'GSL140RDIC',
#  'Dale Washburn (I) (Rep)': 'GSL141RWAS',
#  'Miriam Paris (I) (Dem)': 'GSL142DPAR',
#  'James Beverly (I) (Dem)': 'GSL143DBEV',
#  'Mary Whipple-Lue (Dem)': 'GSL144DWHI',
#  'Danny Mathis (I) (Rep)': 'GSL144RMAT',
#  'Quentin T. Howell (Dem)': 'GSL145DHOW',
#  'Ricky ""Rick"" Williams (I) (Rep)': 'GSL145RWIL',
#  'Shaw Blackmon (I) (Rep)': 'GSL146RBLA',
#  'Stephen Baughier (Dem)': 'GSL147DBAU',
#  'Heath Clark (I) (Rep)': 'GSL147RCLA',
#  'Regina Awung (Dem)': 'GSL148DAWU',
#  'Noel Williams, Jr. (I) (Rep)': 'GSL148RWIL',
#  'Robert Pruitt (Rep)': 'GSL149RPRU',
#  'Matt Hatchett (I) (Rep)': 'GSL150RHAT',
#  'Joyce Barlow (Dem)': 'GSL151DBAR',
#  'Gerald E. Greene (I) (Rep)': 'GSL151RGRE',
#  'Bill Yearta (I) (Rep)': 'GSL152RYEA',
#  'Camia Whitaker Hopson (I) (Dem)': 'GSL153DHOP',
#  'Winfred Dukes (I) (Dem)': 'GSL154DDUK',
#  'Lethia Jones Kittrell (Dem)': 'GSL155DKIT',
#  'Clay Pirkle (I) (Rep)': 'GSL155RPIR',
#  'Greg Morris (I) (Rep)': 'GSL156RMOR',
#  'William ""Bill"" Werkheiser (I) (Rep)': 'GSL157RWER',
#  'Ann P.D. Gleason (Dem)': 'GSL158DGLE',
#  'Butch Parrish (I) (Rep)': 'GSL158RPAR',
#  'Jon G. Burns (I) (Rep)': 'GSL159RBUR',
#  'Jan Tankersley (I) (Rep)': 'GSL160RTAN',
#  'Bill Hitchens (I) (Rep)': 'GSL161RHIT',
#  'Carl Wayne Gilliard (I) (Dem)': 'GSL162DGIL',
#  'Derek J. Mallow (Dem)': 'GSL163DMAL',
#  'Marcus Thompson (Dem)': 'GSL164DTHO',
#  'Ron Stephens (I) (Rep)': 'GSL164RSTE',
#  'Mickey Stephens (I) (Dem)': 'GSL165DSTE',
#  'Michael Mack (Dem)': 'GSL166DMAC',
#  'Jesse Petrea (I) (Rep)': 'GSL166RPET',
#  'Buddy Deloach (Rep)': 'GSL167RDEL',
#  'Al Williams (I) (Dem)': 'GSL168DWIL',
#  'Michael ""Buckle"" Moore (Dem)': 'GSL169DMOO',
#  'Dominic LaRiccia (I) (Rep)': 'GSL169RLAR',
#  'Andre Oliver (Dem)': 'GSL170DOLI',
#  'Penny Houston (I) (Rep)': 'GSL170RHOU',
#  'Joe Campbell (I) (Rep)': 'GSL171RCAM',
#  'Sam Watson (I) (Rep)': 'GSL172RWAT',
#  'Booker T. Gainor (Dem)': 'GSL173DGAI',
#  'Darlene Taylor (I) (Rep)': 'GSL173RTAY',
#  'John L. Corbett (I) (Rep)': 'GSL174RCOR',
#  'John LaHood (I) (Rep)': 'GSL175RLAH',
#  'Evans Primus, Jr. (Dem)': 'GSL176DPRI',
#  'James Burchett (I) (Rep)': 'GSL176RBUR',
#  'Dexter L. Sharper (I) (Dem)': 'GSL177DSHA',
#  'Steven Meeks (I) (Rep)': 'GSL178RMEE',
#  'Julie Jordan (Dem)': 'GSL179DJOR',
#  'Don Hogan (I) (Rep)': 'GSL179RHOG',
#  'Steven Sainz (I) (Rep)': 'GSL180RSAI'}

# %%
df_general["choice"] = np.where(df_general["contest"].isin(["Statewide Referendum A",'Constitutional Amendment #1', 'Constitutional Amendment #2']), df_general["contest"]+df_general["choice"], df_general["choice"])

# %%
df_general["choice"] = df_general["choice"].str.strip()

# %%
cand_update_dict = {'Jill  Prouty (Dem)':'Jill Prouty (Dem)', 
                   'Constitutional Amendment #1YES':'Amendment #1 "Yes"',
                    'Constitutional Amendment #1NO':'Amendment #1 "No"',
                   'Constitutional Amendment #2YES':'Amendment #2 "Yes"',
                    'Constitutional Amendment #2NO':'Amendment #2 "No"',
                   'Statewide Referendum AYES':'Referendum A "Yes"',
                    'Statewide Referendum ANO':'Referendum A "No"'}

# %%
df_general["choice"] = df_general["choice"].map(cand_update_dict).fillna(df_general["choice"])
# df_general["choice"] = df_general["choice"].str.replace("  ", " ")

# %%
df_general["Clean_Cand"] = df_general["choice"].map(fields_dict).fillna("n/a")

# %%
df_general["Clean_Cand"].value_counts()
# Out:
# G20RFANO      636
# G20A02NO      636
# G20A01NO      636
# G20A02YES     636
# G20A01YES     636
#              ...
# GSL057DEVA      4
# GSL058DCAN      4
# GSL059DDRE      4
# GSL074DNEA      4
# GSL047DCAR      4
# Name: Clean_Cand, Length: 388, dtype: int64

# %%
df_general["num_votes"] = df_general["num_votes"].astype(int)

# %%
df_general_pivoted = pd.pivot_table(df_general, index = "county", columns = "Clean_Cand", values = "num_votes", aggfunc = sum)

# %%
df_general_pivoted.reset_index(inplace = True, drop = False)

# %%
df_general_pivoted = df_general_pivoted.fillna(0)

# %%
for val in list(df_general_pivoted.columns):
    if val != "county":
        df_general_pivoted[val] = df_general_pivoted[val].astype(int)

# %%
df_general_pivoted.to_csv("./cleaned_official_county_totals.csv", index = False)
