# %%
import pandas as pd
import geopandas as gp
import numpy as np 
import os
import fiona
from statistics import mean, median
import string
import re
from collections import Counter
from matplotlib.lines import Line2D

# %%
pd.set_option('display.max_columns', 500)

# %%
'''Following Docstring Convention: https://www.python.org/dev/peps/pep-0257/'''

import pandas as pd
import os
#THESE SETTINGS ESSENTIAL TO HAVE THE FIELDS TABLE SHOW UP CORRECTLY in the readme
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

def create_fields_table(fields_dict):
    '''Fields table used in readme'''
    fields_table_data = {'Field Name': list(fields_dict.keys()), 'Description': list(fields_dict.values())}
    fields_table = pd.DataFrame(fields_table_data)
    return fields_table

def erj_readme_template(fields_dict, stateabrv, state, year, election_type, additional_races, retrieval_date, upload_date, vest_file_link, 
                        raw_data_source, state_erj_repo, office_codes, additional_notes=' '):
    '''erj_readme_template variable explanations:
    fields_dict = used to create the fields table for the non-standardized/race fields fields. 
                Key is the field/value is the field description
    stateabrv = two character state abbreviation capitalized, 
    state = state name, first letter capitalized, 
    year = election year (XXXX), 
    election_type = general, primary, special or runoff, 
    additional_races = the races that RDH added to the original vest file (not in VEST's og file), 
    retrieval_date = date RDH retrieved VEST file, 
    upload_date = date RDH uploads ERJ file, 
    vest_file_link = link to dataverse page for VEST's precinct boundary and election results file, 
    raw_data_source = site description and link, 
    state_erj_repo = link to erj github repository for given state
    office_codes = codes used broken off of field names for easy viewing
    additional_notes = default set to empty, but fill in with string where applicable.
    '''
    #Generalized readme text
    readme_p1 = '''{year} {stateabrv} {election_type} election results
## RDH Date Retrieval
{retrieval_date}
## RDH Upload Date
{upload_date}
## Sources
The RDH retrieved the VEST {year} {election_type} precinct boundary and election results shapefile from [VEST's Harvard Dataverse]({vest_file_link})
The RDH retrieved raw {year} {election_type} election results from {raw_data_source}
## Notes on Field Names (adapted from VEST):
Columns reporting votes generally follow the pattern: 
One example is:
G16PREDCLI
The first character is G for a general election, P for a primary, S for a special, and R for a runoff.
Characters 2 and 3 are the year of the election.*
Characters 4-6 represent the office type (see list below).
Character 7 represents the party of the candidate.
Characters 8-10 are the first three letters of the candidate's last name.
To fit within the GIS 10 character limit for field names, the naming convention is slightly different for the State Legislature and 
US House of Representatives. All fields are listed below with definitions.
Office Codes Used:
{office_codes}
## Fields:
    '''.format(stateabrv= stateabrv, state= state, year=year, election_type=election_type, additional_races=additional_races,retrieval_date=retrieval_date,
    upload_date=upload_date, vest_file_link=vest_file_link, raw_data_source=raw_data_source, state_erj_repo=state_erj_repo, office_codes=office_codes)

    fields_table = create_fields_table(fields_dict)
    readme_p2 = str(fields_table.to_string(index = False))

    readme_p3='''
    
## Processing Steps
    
The RDH joined additional election results to VEST's existing precinct shapefile, including {additional_races} using Python.
For more information on the processing completed, visit our [Github repository]({state_erj_repo}) for Election Result Joins (ERJ) for {state}.
## Additional Notes
{additional_notes}
Please contact info@redistrictingdatahub.org for more information.
    '''.format(stateabrv=stateabrv, state=state, year=year, election_type=election_type, additional_races=additional_races, state_erj_repo=state_erj_repo, office_codes=office_codes, additional_notes = additional_notes)
    
    full_readme = str(readme_p1)+str(readme_p2)+str(readme_p3)
    return full_readme

def export_readme(readme_name, state, election_type, full_readme_text):
    '''readme_name must include file path to readme within erj folder
    ex: 
    readme_name = './az_gen_20_prec/readme.txt'
    '''
    with open(readme_name, 'x') as tf:
        tf.write(full_readme_text)
    print(state, election_type, " readme moved to folder")

# %%
def export_readme(readme_name, state, election_type, full_readme_text):
    '''readme_name must include file path to readme within erj folder
    ex: 
    readme_name = './az_gen_20_prec/readme.txt'
    '''
    if os.path.exists(readme_name):
        os.remove(readme_name)
    with open(readme_name, 'x') as tf:
        tf.write(full_readme_text)
    print(state, election_type, " readme moved to folder")

# %%
fields_dict = {}

# %%
import os

fields_dict = {}

field_csv = pd.read_csv("./primary_fields_dict.csv")
fields_dict = dict(zip(field_csv["Field_Name"], field_csv["Cand_Name"]))

# %%
fields_dict
# Out:
# {'P20PREDBEN': 'Michael Bennet',
#  'P20PREDBID': 'Joseph R. Biden',
#  'P20PREDBLO': 'Michael R. Bloomberg',
#  'P20PREDBUT': 'Pete Buttigieg',
#  'P20PREDDEL': 'John K. Delaney',
#  'P20PREDGAB': 'Tulsi Gabbard',
#  'P20PREDKLO': 'Amy Klobuchar',
#  'P20PREDPAT': 'Deval Patrick',
#  'P20PREDSAN': 'Bernie Sanders',
#  'P20PREDSTE': 'Tom Steyer',
#  'P20PREDWAR': 'Elizabeth Warren',
#  'P20PREDYAN': 'Andrew Yang',
#  'P20PRERTRU': 'Donald J. Trump (I)',
#  'P20PSCDBLA': 'Daniel Blackman',
#  'P20PSCDBRY': 'Robert G. Bryant',
#  'P20PSCDNOE': 'John Noel',
#  'P20PSCRMCD': 'Lauren Bubba McDonald, Jr. (I)',
#  'P20PSCRSHA': 'Jason Shaw (I)',
#  'P20USSDAMI': 'Sarah Riggs Amico',
#  'P20USSDDEJ': 'Marckeith DeJesus',
#  'P20USSDKNO': 'James Knox',
#  'P20USSDMCC': 'Tricia Carpenter McCracken',
#  'P20USSDOSS': 'Jon Ossoff',
#  'P20USSDSMI': 'Maya Dillard Smith',
#  'P20USSDTOM': 'Teresa Pike Tomlinson',
#  'P20USSRPER': 'David A. Perdue (I)',
#  'PCON01DGRI': 'Joyce Marie Griggs',
#  'PCON01DRIN': 'Lisa M. Ring',
#  'PCON01DSEI': 'Barbara Seidman',
#  'PCON01RCAR': 'Earl L. ""Buddy"" Carter (I)',
#  'PCON01RMER': 'Danny Merritt',
#  'PCON01RYAS': 'Ken Yasger',
#  'PCON02DBIS': 'Sanford Bishop (I)',
#  'PCON02RCHI': 'Vivian L. Childs',
#  'PCON02RCOL': 'Don Cole',
#  'PCON03DALM': 'Val Almonord',
#  'PCON03RFER': 'Drew Ferguson (I)',
#  'PCON04DHAS': 'William Haston',
#  'PCON04DJOH': 'Henry C. "Hank" Johnson, Jr. (I)',
#  'PCON04DNIE': 'Elaine Amankwah Nietmann',
#  'PCON04REZA': 'Johsie Cruz Ezammudeen',
#  'PCON05DLEW': 'John R. Lewis (I)',
#  'PCON05DMAR': 'Barrington D. Martin, II',
#  'PCON05RSTA': 'Angela Stanton-King',
#  'PCON06DMCB': 'Lucy McBath (I)',
#  'PCON06RBAR': 'Mykel Lynn Barthelemy',
#  'PCON06RHAN': 'Karen Handel',
#  'PCON06RHAR': 'Blake Harbin',
#  'PCON06RPRO': 'Joe Profit',
#  'PCON06RSMI': 'Paulette Smith',
#  'PCON07DBOU': 'Carolyn Bourdeaux',
#  'PCON07DEAV': 'John Eaves',
#  'PCON07DISL': 'Nabilah Aishah Islam',
#  'PCON07DKAR': 'Zahra S. Karinshak',
#  'PCON07DMAL': 'Rashid Malik',
#  'PCON07DROM': 'Brenda Lopez Romero',
#  'PCON07RBAB': 'Lisa Noel Babbage',
#  'PCON07RGON': 'Mark Gonsalves',
#  'PCON07RHOM': 'Lynne Homrich',
#  'PCON07RKEN': 'Zachary H. Kennemore',
#  'PCON07RMCC': 'Rich McCormick',
#  'PCON07RUNT': 'Renee S. Unterman',
#  'PCON07RYU': 'Eugene Yu',
#  'PCON08DHOL': 'Lindsay Holliday',
#  'PCON08RDEA': 'Vance Dean',
#  'PCON08RELL': 'Danny Ellyson',
#  'PCON08RSCO': 'Austin Scott (I)',
#  'PCON09DPAN': 'Devin Pandy',
#  'PCON09DSIS': 'Brooke Siskin',
#  'PCON09DWIL': 'Dan Wilson',
#  'PCON09RBOG': 'Michael Boggus',
#  'PCON09RBRO': 'Paul Broun',
#  'PCON09RCLY': 'Andrew Clyde',
#  'PCON09RGUR': 'Matt Gurtler',
#  'PCON09RSTR': 'Maria Strickland',
#  'PCON09RTAN': 'Kevin Tanner',
#  'PCON09RUND': 'Ethan Underwood',
#  'PCON09RWEE': 'Kellie Weeks',
#  'PCON09RWIL': 'John K. Wilkinson',
#  'PCON10DFER': 'Andrew Ferguson',
#  'PCON10DJOH': 'Tabitha Johnson-Green',
#  'PCON10RHIC': 'Jody Hice (I)',
#  'PCON11DBAR': 'Dana Barrett',
#  'PCON11RLOU': 'Barry Loudermilk (I)',
#  'PCON12DJOH': 'Liz Johnson',
#  'PCON12DSTE': 'Dan Steiner',
#  'PCON12RALL': 'Rick W. Allen (I)',
#  'PCON13DOWE': 'Michael Owens',
#  'PCON13DPET': 'Jannquell Peters',
#  'PCON13DSCO': 'David Scott (I)',
#  'PCON13DWAI': 'Keisha Sean Waites',
#  'PCON13RGON': 'Caesar Gonzales',
#  'PCON13RHIT': 'Becky E. Hites',
#  'PCON14DAUS': 'Kevin Van Ausdal',
#  'PCON14RBAR': 'John D. Barge',
#  'PCON14RBUL': 'Ben Bullock',
#  'PCON14RCOO': 'Kevin Cooke',
#  'PCON14RCOW': 'John Cowan',
#  'PCON14RFUL': 'Clayton Fuller',
#  'PCON14RGRE': 'Marjorie Taylor Greene',
#  'PCON14RGUN': 'Andy Gunther',
#  'PCON14RHEM': 'Bill Hembree',
#  'PCON14RLAU': 'Matt Laughridge',
#  'PSL001RCAM': 'Mike Cameron',
#  'PSL001RDEF': 'John Deffenbaugh',
#  'PSL001RMIL': 'Vikki Mills',
#  'PSL002RTAR': 'Steve Tarvin (I)',
#  'PSL003RHIL': 'Dewayne Hill (I)',
#  'PSL003RHOL': 'Jeff Holcomb',
#  'PSL004RCAR': 'Kasey Carpenter (I)',
#  'PSL005RBAR': 'Matt Barton (I)',
#  'PSL006RRID': 'Jason T. Ridley (I)',
#  'PSL007DDAY': 'Rick D. Day',
#  'PSL007RRAL': 'David Ralston (I)',
#  'PSL008DCOO': 'Dave Cooper',
#  'PSL008RGUN': 'Stan Gunter',
#  'PSL008RTOW': 'Steve Townsend',
#  'PSL009DRAV': 'Sharon L. Ravert',
#  'PSL009RLEI': 'Steve Leibel',
#  'PSL009RSHE': 'Doug Sherrill',
#  'PSL009RSMI': 'Clint Smith',
#  'PSL009RTOL': 'Tyler Tolin',
#  'PSL009RTUM': 'Zack Tumlin',
#  'PSL009RWAD': 'Will Wade',
#  'PSL010DMIT': 'Nick Mitchell',
#  'PSL010RAND': 'Victor E. Anderson',
#  'PSL010RCRU': 'Robert A. Crumley',
#  'PSL010RDEA': 'Jimmy Dean',
#  'PSL011DHOL': 'Kayla Hollifield',
#  'PSL011RJAS': 'Rick Jasperse (I)',
#  'PSL011RWIL': 'Charlotte L. Williamson',
#  'PSL012DGIL': 'Jonathan Gilreath-Harvey',
#  'PSL012RLUM': 'Eddie Lumsden (I)',
#  'PSL013RBAR': 'Brad Barnes',
#  'PSL013RDEM': 'Katie Dempsey (I)',
#  'PSL014RSCO': 'Mitchell Scoggins (I)',
#  'PSL015RGAM': 'Matthew Gambill (I)',
#  'PSL016DARR': 'Lyndsay Arrendale',
#  'PSL016RHUL': 'Jennifer Lankford Hulsey',
#  'PSL016RKEL': 'Trey Kelley (I)',
#  'PSL017DDAI': 'Q. Dailey',
#  'PSL017RMOM': 'Martin Momtahan (I)',
#  'PSL018DRHU': 'Pat Rhudy',
#  'PSL018RDAN': 'Lane Daniel',
#  'PSL018RHIG': 'Cason Hightower',
#  'PSL018RSMI': 'Tyler Paul Smith',
#  'PSL019DFEL': 'Alison Feliciano',
#  'PSL019RGUL': 'Joseph Gullett (I)',
#  'PSL020DLEN': 'Ginny Lennox',
#  'PSL020RBAL': 'Rick Ballew',
#  'PSL020RBYR': 'Charlice Byrd',
#  'PSL020RLON': 'Jessica L. Long',
#  'PSL020RRID': 'Jordan Ridley',
#  'PSL020RSIN': 'Katrina Singletary',
#  'PSL021DHUG': 'William D. Hughes',
#  'PSL021RFIN': 'Bill Fincher',
#  'PSL021RSAG': 'Rajpal ""Raj\' Sagoo',
#  'PSL021RTHO': 'Brad Thomas',
#  'PSL022DRAV': 'Charles Ravenscraft',
#  'PSL022DSIM': 'Bobbi L. Simpson',
#  'PSL022RCAN': 'Wes Cantrell (I)',
#  'PSL023RBAL': 'Mandi L. Ballinger (I)',
#  'PSL024DBUC': 'Natalie Bucsko',
#  'PSL024RGIL': 'Sheri Smallwood Gilligan (I)',
#  'PSL025DOLE': 'Christa Olenczak',
#  'PSL025RJON': 'Todd Jones (I)',
#  'PSL026DBOS': 'Jason Boskey',
#  'PSL026RMCD': 'Lauren W. McDonald, III',
#  'PSL027RHAW': 'Lee Hawkins (I)',
#  'PSL028RERW': 'Chris Erwin (I)',
#  'PSL029DCAL': 'Pat Calmes',
#  'PSL029RDUB': 'Matt Dubnik (I)',
#  'PSL030DMIL': 'Leigh Miller',
#  'PSL030RDUN': 'Emory Dunahoo, Jr. (I)',
#  'PSL031DFUL': 'Pete Fuller',
#  'PSL031RBEN': 'Tommy Benton (I)',
#  'PSL032DALL': 'Alisha Allen',
#  'PSL032RPOW': 'Alan Powell (I)',
#  'PSL033DHAM': 'Kerry Dornell Hamm',
#  'PSL033RAZE': 'Bruce Azevedo',
#  'PSL033RLEV': 'Rob Leverett',
#  'PSL033RSTR': 'Tripp Strickland',
#  'PSL034DSMI': 'Priscilla G. Smith',
#  'PSL034RREE': 'Bert Reeves (I)',
#  'PSL035DCAM': 'Lisa Campbell',
#  'PSL035DRIN': 'Kyle Rinaudo',
#  'PSL035DWEB': 'Elizabeth Webster',
#  'PSL035RSET': 'Ed Setzler (I)',
#  'PSL036DRYN': 'James Francis Ryner',
#  'PSL036REHR': 'Ginny Ehrhart (I)',
#  'PSL037DWIL': 'Mary Frances Williams (I)',
#  'PSL037RWIN': 'Rose Wing',
#  'PSL038DWIL': 'David Wilkerson (I)',
#  'PSL039DCUM': 'Terry Alexis Cummings',
#  'PSL039DTHO': 'Erica Thomas (I)',
#  'PSL039RHIC': 'Jim Hickey',
#  'PSL040DALL': 'Erick Eugene Allen (I)',
#  'PSL040RBOW': 'Taryn Chilivis Bowman',
#  'PSL041DSMI': 'Michael Smith (I)',
#  'PSL041RGEO': 'Stephen M. George, Jr.',
#  'PSL042DANU': 'Teri Anulewicz (I)',
#  'PSL042DNUC': 'Asher Nuckolls',
#  'PSL043DWAK': 'Luisa Wakeman',
#  'PSL043RCOO': 'Sharon Cooper (I)',
#  'PSL044DDIC': 'Connie DiCicco',
#  'PSL044RPAR': 'Don L. Parsons (I)',
#  'PSL045DGHA': 'Sara Tindall Ghazal',
#  'PSL045RDOL': 'Matt Dollar (I)',
#  'PSL046DHOL': 'Caroline L. Holko',
#  'PSL046DRIT': 'Shirley Ritchie',
#  'PSL046RCAR': 'John Carson (I)',
#  'PSL047DCAR': 'Anthia Owens Carter',
#  'PSL047RJON': 'Jan Jones (I)',
#  'PSL048DROB': 'Mary Robichaux (I)',
#  'PSL048RPRI': 'Betty Price',
#  'PSL049DHAY': 'Jason T. Hayes',
#  'PSL049DLAW': 'Ken Lawler',
#  'PSL049RMAR': 'Charles E. ""Chuck"" Martin (I)',
#  'PSL050DKAU': 'Angelika Kausche (I)',
#  'PSL050RLIN': 'Jay Lin',
#  'PSL051DMCL': 'Josh McLaurin (I)',
#  'PSL051RKAU': 'Alex B. Kaufman',
#  'PSL052DROB': 'Shea Roberts',
#  'PSL052RSIL': 'Deborah Silcox (I)',
#  'PSL053DJON': 'Sheila Jones (I)',
#  'PSL054DHOL': 'Betsy Holland (I)',
#  'PSL054RRUD': 'Lyndsey Rudder',
#  'PSL055DMET': 'Marie Metze (I)',
#  'PSL055DQUI': 'Fred Quinn Jr',
#  'PSL056DMAI': 'Mesha Mainor',
#  'PSL056DMCN': 'Josh McNair',
#  'PSL056DTER': 'Darryl J. Terry, II',
#  'PSL057DEVA': 'Stacey Evans',
#  'PSL057DLAM': 'Kyle Lamont',
#  'PSL057DSHE': 'Jenne Shepherd',
#  'PSL057DWAN': 'Alex Wan',
#  'PSL058DCAN': 'Park Cannon (I)',
#  'PSL059DDRE': 'David Dreyer (I)',
#  'PSL060DSCH': 'Kim Schofield (I)',
#  'PSL061DBRU': 'Roger Bruce (I)',
#  'PSL062DBOD': 'William K. Boddie, Jr. (I)',
#  'PSL063DBAZ': 'Debra Bazemore (I)',
#  'PSL063DKIN': 'Kenneth ""Ken"" Kincaid',
#  'PSL063RCAL': 'David Callahan',
#  'PSL064DJAC': 'Derrick L. Jackson (I)',
#  'PSL065DBEA': 'Sharon Beasley-Teague (I)',
#  'PSL065DDOS': 'Amber Doss-Hunter',
#  'PSL065DTHO': 'Mandisha A. Thomas',
#  'PSL066DALE': 'Kimberly Alexander (I)',
#  'PSL066RJON': 'Jason C. Jones',
#  'PSL067DMAY': 'Angela Mayfield',
#  'PSL067RGRA': 'Micah Gravley (I)',
#  'PSL068RCOL': 'J. Collins (I)',
#  'PSL069DGIL': 'Herbert Giles',
#  'PSL069RNIX': 'Randy Nix (I)',
#  'PSL070RSMI': 'Lynn Smith (I)',
#  'PSL071DPRO': 'Jill Prouty',
#  'PSL071RSAK': 'Marcy Westmoreland Sakrison',
#  'PSL071RSIN': 'Philip Singleton (I)',
#  'PSL072DROV': 'Fred Rovner',
#  'PSL072RBON': 'Josh Bonner (I)',
#  'PSL073DHAR': 'William Harris',
#  'PSL073RMAT': 'Karen Mathiak (I)',
#  'PSL074DMAS': 'Angel Massey',
#  'PSL074DNEA': 'Yasmin Neal',
#  'PSL075DGLA': 'Mike Glanton (I)',
#  'PSL076DSCO': 'Sandra Givens Scott (I)',
#  'PSL077DBUR': 'Rhonda Burnough (I)',
#  'PSL078DDOU': 'Demetrius Douglas (I)',
#  'PSL078DJEA': 'Attania Jean-Funny',
#  'PSL078DWAL': 'Ron Walker',
#  'PSL079DWIL': 'Michael S. Wilensky (I)',
#  'PSL079RJOH': 'Andrea Johnson',
#  'PSL080DWIL': 'Matthew Wilson (I)',
#  'PSL080RCOL': 'Alan Cole',
#  'PSL081DHOL': 'Scott Holcomb (I)',
#  'PSL082DOLI': 'Mary Margaret Oliver (I)',
#  'PSL083DEVA': 'Becky Evans (I)',
#  'PSL083DMAL': 'Audrey Maloof',
#  'PSL084DCOD': 'Harmel ""Mel"" Codi',
#  'PSL084DSHA': 'Renitta Shannon (I)',
#  'PSL085DDRE': 'Karla Drenner (I)',
#  'PSL086DBOL': 'Ladena Bolton',
#  'PSL086DHEN': 'Michele Henson (I)',
#  'PSL086DLOP': 'Zulma Lopez',
#  'PSL086DONE': "Joscelyn C. O'Neil",
#  'PSL087DDAV': 'Viola Davis (I)',
#  'PSL088DMIT': 'Billy Mitchell (I)',
#  'PSL089DNGU': 'Bee Nguyen (I)',
#  'PSL089DRID': 'Marcia Ridley',
#  'PSL090DSHE': 'Greg Shealey',
#  'PSL090DSTE': 'Pam Stephenson (I)',
#  'PSL090DWAT': 'Stan Watson',
#  'PSL091DTAY': 'Rhonda S. Taylor',
#  'PSL092DCAR': 'Doreen Carter (I)',
#  'PSL093DKEN': "Dar'Shun Kendrick (I)",
#  'PSL093DREY': 'Alfred Reynolds',
#  'PSL093ROWE': 'Hubert Owens, Jr.',
#  'PSL094DBEN': 'Karen Bennett (I)',
#  'PSL095DMOO': 'Beth Moore (I)',
#  'PSL095RMCC': 'Erica McCurdy',
#  'PSL096DMAR': 'Pedro ""Pete"" Marin (I)',
#  'PSL097DCAM': 'Mary Blackmon Campbell',
#  'PSL097RRIC': 'Bonnie Rich (I)',
#  'PSL098DCHO': 'Taeho Cho',
#  'PSL098RCLA': 'David Clark (I)',
#  'PSL099DGRA': 'Jorge Granados',
#  'PSL099DLIM': 'Marvin Lim',
#  'PSL100DMCC': 'Dewey L. McClain (I)',
#  'PSL101DPAR': 'Sam Park (I)',
#  'PSL101RFIE': 'Carol Field',
#  'PSL102DKEN': 'Gregg Kennard (I)',
#  'PSL102RHON': 'Soo Hong',
#  'PSL103DMAR': 'Clifton Marshall',
#  'PSL103RBAR': 'Timothy Barr (I)',
#  'PSL103RMCC': 'Derrick McCollum',
#  'PSL103RSCH': 'Donald Schmidt',
#  'PSL104DHEM': 'Nakita Hemingway',
#  'PSL104DSTE': 'Andrea Stephenson',
#  'PSL104REFS': 'Chuck Efstration (I)',
#  'PSL105DMCL': 'Donna McLeod (I)',
#  'PSL105RDIE': 'Eric Dierks',
#  'PSL106DLES': 'Emily Leslie',
#  'PSL106DMIT': 'Rebecca Mitchell',
#  'PSL106RHAR': 'Brett Harrell (I)',
#  'PSL107DHUT': 'Shelly Hutchinson (I)',
#  'PSL107RMCC': 'Michael McConnell',
#  'PSL108DCLA': 'Jasmine Clark (I)',
#  'PSL108RCRI': 'Johnny Crist',
#  'PSL109DLEW': 'Regina Lewis-Ward',
#  'PSL109RRUT': 'Dale Rutledge (I)',
#  'PSL110DCAR': 'Ebony Carter',
#  'PSL110RCRO': 'Clint Crowe',
#  'PSL111DDUN': 'Tarji Leonard Dunn',
#  'PSL111DHOL': 'El-Mahdi Holly (I)',
#  'PSL112RBEL': 'Dave Belton (I)',
#  'PSL113DDIC': 'Pam Dickerson (I)',
#  'PSL113DHEN': 'Sharon Henderson',
#  'PSL114RKIR': 'Tom Kirby (I)',
#  'PSL115DREE': 'Debbie Reed',
#  'PSL115RWIL': 'Bruce Williamson (I)',
#  'PSL116RENG': 'Terry England (I)',
#  'PSL117DJOH': '""Mokah"" Jasmine Johnson',
#  'PSL117RGAI': 'Houston Gaines (I)',
#  'PSL118DFRY': 'Spencer Frye (I)',
#  'PSL119DWAL': 'Jonathan Wallace',
#  'PSL119RWIE': 'Marcus A. Wiedower (I)',
#  'PSL120RRHO': 'Trey Rhodes (I)',
#  'PSL121RFLE': 'Barry Fleming (I)',
#  'PSL122DCRU': 'Doris O. Crutchfield',
#  'PSL122RLOT': 'Jodi Lott (I)',
#  'PSL123RNEW': 'Mark Newton (I)',
#  'PSL124DHOW': 'Henry ""Wayne"" Howard (I)',
#  'PSL125DNEL': 'Sheila Clark Nelson (I)',
#  'PSL126DFRA': 'Gloria Frazier (I)',
#  'PSL127DPRI': 'Brian L. Prince (I)',
#  'PSL128DJAC': 'Mack Jackson (I)',
#  'PSL128DTHO': 'Daniel "Danny" Thomas, Jr.',
#  'PSL129DBEL': 'Sharonda Bell',
#  'PSL129RHOL': 'Susan Holmes (I)',
#  'PSL130DHEN': 'Sheila Henley',
#  'PSL130RKNI': 'David Knight (I)',
#  'PSL131DBEN': 'Chris Benton',
#  'PSL131RCAM': 'Beth Camp',
#  'PSL131RCOG': 'Kenny Coggins',
#  'PSL132DMAN': 'Frederick Manley',
#  'PSL132DTRA': 'Bob Trammell, Jr. (I)',
#  'PSL132RJEN': 'David Jenkins',
#  'PSL132RKIN': 'Gene King',
#  'PSL133RSMI': 'Vance Smith, Jr. (I)',
#  'PSL134DSPR': 'Carl Sprayberry',
#  'PSL134DTAU': 'William Tauxe',
#  'PSL134RSMI': 'Richard H. Smith (I)',
#  'PSL135DSMY': 'Calvin Smyre (I)',
#  'PSL136DHUG': 'Carolyn Hugley (I)',
#  'PSL137DBUC': 'Debbie G. Buckner (I)',
#  'PSL138DARN': 'Marc Arnett',
#  'PSL138RCHE': 'Mike Cheokas (I)',
#  'PSL139DBEN': 'Patty Bentley (I)',
#  'PSL140RDIC': 'Robert Dickey (I)',
#  'PSL141RWAS': 'Dale Washburn (I)',
#  'PSL142DPAR': 'Miriam Paris (I)',
#  'PSL143DBEV': 'James Beverly (I)',
#  'PSL144DWHI': 'Mary Whipple-Lue',
#  'PSL144RMAT': 'Danny Mathis (I)',
#  'PSL145DBYR': 'Nincoe Byrd',
#  'PSL145DHOW': 'Quentin T. Howell',
#  'PSL145RWIL': 'Ricky ""Rick"" Williams (I)',
#  'PSL146RBLA': 'Shaw Blackmon (I)',
#  'PSL147DBAU': 'Stephen Baughier',
#  'PSL147RBRI': 'Miranda Britt',
#  'PSL147RCLA': 'Heath Clark (I)',
#  'PSL148DAWU': 'Regina Awung',
#  'PSL148RWIL': 'Noel Williams, Jr. (I)',
#  'PSL149RPRU': 'Robert Pruitt',
#  'PSL149RSTE': 'Chris Steverson',
#  'PSL150RHAT': 'Matt Hatchett (I)',
#  'PSL151DBAR': 'Joyce Barlow',
#  'PSL151RGRE': 'Gerald E. Greene (I)',
#  'PSL152RROL': 'Dennis Roland',
#  'PSL152RYEA': 'Bill Yearta (I)',
#  'PSL153DHOP': 'Camia Whitaker Hopson (I)',
#  'PSL153DMAT': 'Henry Mathis, Jr.',
#  'PSL154DDUK': 'Winfred Dukes (I)',
#  'PSL155DKIT': 'Lethia Jones Kittrell',
#  'PSL155RPIR': 'Clay Pirkle (I)',
#  'PSL156RMOR': 'Greg Morris (I)',
#  'PSL157RWER': 'William ""Bill"" Werkheiser (I)',
#  'PSL158DGLE': 'Ann P.D. Gleason',
#  'PSL158RPAR': 'Butch Parrish (I)',
#  'PSL159RBUR': 'Jon G. Burns (I)',
#  'PSL160RTAN': 'Jan Tankersley (I)',
#  'PSL161RHIT': 'Bill Hitchens (I)',
#  'PSL162DGIL': 'Carl Wayne Gilliard (I)',
#  'PSL163DMAL': 'Derek J. Mallow',
#  'PSL163DSIM': 'Mac Sims',
#  'PSL163DSMI': 'Marc Smith',
#  'PSL163DSWA': 'Matthew J. Swanson',
#  'PSL163DWES': 'Anne Allen Westbrook',
#  'PSL164DRAY': 'Jeffrey D. Rayno',
#  'PSL164DTHO': 'Marcus Thompson',
#  'PSL164RSTE': 'Ron Stephens (I)',
#  'PSL165DSTE': 'Mickey Stephens (I)',
#  'PSL165DYOU': 'Clinton Young',
#  'PSL166DMAC': 'Michael Mack',
#  'PSL166RPET': 'Jesse Petrea (I)',
#  'PSL167RDEL': 'Buddy Deloach',
#  'PSL167RJON': 'Jeff Jones (I)',
#  'PSL168DWIL': 'Al Williams (I)',
#  'PSL169DMOO': 'Michael ""Buckle"" Moore',
#  'PSL169RLAR': 'Dominic LaRiccia (I)',
#  'PSL170DOLI': 'Andre Oliver',
#  'PSL170RHOU': 'Penny Houston (I)',
#  'PSL171RCAM': 'Joe Campbell (I)',
#  'PSL172RWAT': 'Sam Watson (I)',
#  'PSL173DGAI': 'Booker T. Gainor',
#  'PSL173RTAY': 'Darlene Taylor (I)',
#  'PSL174RCOR': 'John L. Corbett (I)',
#  'PSL175RLAH': 'John LaHood (I)',
#  'PSL176DPRI': 'Evans Primus, Jr.',
#  'PSL176RBUR': 'James Burchett (I)',
#  'PSL177DPAY': 'Alvin Payton, Jr.',
#  'PSL177DSHA': 'Dexter L. Sharper (I)',
#  'PSL178RMEE': 'Steven Meeks (I)',
#  'PSL179DJOR': 'Julie Jordan',
#  'PSL179RHOG': 'Don Hogan (I)',
#  'PSL180RSAI': 'Steven Sainz (I)',
#  'PSU01DMCG': 'Kerri Wilkins McGinty',
#  'PSU01RWAT': 'Ben Watson (I)',
#  'PSU02DJAC': 'Lester G. Jackson, III (I)',
#  'PSU03RMCN': 'Sheila McNeill',
#  'PSU03RSHA': 'David Sharpe',
#  'PSU03RSMI': 'Cody Smith',
#  'PSU04RBOH': 'Scott Bohlke',
#  'PSU04RHIC': 'Billy Hickman',
#  'PSU04RPAL': 'Kathy Palmer',
#  'PSU04RSIN': 'Neil Singleton',
#  'PSU05DRAH': 'Sheikh Rahman (I)',
#  'PSU06DJOR': 'Jennifer ""Jen"" Jordan (I)',
#  'PSU06RLAN': 'Harrison Lance',
#  'PSU07RHAR': 'Tyler Harper (I)',
#  'PSU08DGEA': 'Treva Gear',
#  'PSU08RGOO': 'Russ Goodman',
#  'PSU10DJON': 'Emanuel Jones (I)',
#  'PSU10DRAE': 'Maurice Raeford',
#  'PSU11RBUR': 'Dean Burke (I)',
#  'PSU12DBAL': 'Edward Ford Ball',
#  'PSU12DSIM': 'Freddie Powell Sims (I)',
#  'PSU12RTAY': 'Tracy Taylor',
#  'PSU13DEGL': 'Mary Egler',
#  'PSU13DMEL': 'Ruenett Melton',
#  'PSU13RBOW': 'Spud Bowen',
#  'PSU13RSUM': 'Carden H. Summers (I)',
#  'PSU14DJOH': 'Travis Johnson',
#  'PSU14RTHO': 'Bruce Thompson (I)',
#  'PSU15DHAR': 'Ed Harbison (I)',
#  'PSU15DREE': 'Teddy Reese',
#  'PSU16DJES': 'Cinquez Jester',
#  'PSU16RHAR': 'Marty Harbin (I)',
#  'PSU17DROS': 'Kelly Rose',
#  'PSU17RSTR': 'Brian Strickland (I)',
#  'PSU18RKEN': 'John F. Kennedy (I)',
#  'PSU19RTIL': 'Blake Tillery (I)',
#  'PSU20DJOH': 'Julius Newberry Johnson',
#  'PSU20RWAL': 'Larry Walker (I)',
#  'PSU20RWET': 'Franklin E. Wetmore',
#  'PSU21RBEA': 'Brandon Beach (I)',
#  'PSU21RCAL': 'Michael Caldwell',
#  'PSU22DJON': 'Harold V. Jones, II (I)',
#  'PSU23DSMI': 'Ceretta Smith',
#  'PSU23RALL': 'Trey Allen',
#  'PSU23RBUR': 'Max Burns',
#  'PSU24RAND': 'Lee Anderson (I)',
#  'PSU25DBRI': 'Veronica Brinson',
#  'PSU25RJON': 'Burt Jones (I)',
#  'PSU26DSR.': 'David E. Lucas, Sr. (I)',
#  'PSU26DWEA': 'Verbin Weaver',
#  'PSU27DGRI': 'Brooke Griffiths',
#  'PSU27RDOL': 'Greg Dolezal (I)',
#  'PSU28RBRA': 'Matt Brass (I)',
#  'PSU29RROB': 'Randy Robertson (I)',
#  'PSU30DEDW': 'Montenia Edwards',
#  'PSU30DEGU': 'Afoma Eguh-Okafor',
#  'PSU30DJAM': 'Triana Arnold James',
#  'PSU30RDUG': 'Mike Dugan (I)',
#  'PSU31DSMI': 'Tianna Smith',
#  'PSU31RANA': 'Jason Anavitarte',
#  'PSU31RAUS': 'Boyd Austin',
#  'PSU31RMEH': 'Robert ""Bobby"" Mehan',
#  'PSU31RWIL': 'Bobby Wilson',
#  'PSU32DTRI': 'Christine Triebsch',
#  'PSU32RKIR': 'Kay Kirkpatrick (I)',
#  'PSU33DRHE': 'Michael Rhett (I)',
#  'PSU34DSEA': 'Valencia M. Seay (I)',
#  'PSU35DASH': 'Karen W. Ashley',
#  'PSU35DJAM': 'Donzella James (I)',
#  'PSU35DJOH': 'Kelly Johnson',
#  'PSU36DORR': 'Nan Orrock (I)',
#  'PSU37DPAR': 'Vanessa Parker',
#  'PSU37DREN': 'Turner Rentz, III',
#  'PSU37RTIP': 'Lindsey Tippins (I)',
#  'PSU38DBAR': 'Devin Barrington-Ward',
#  'PSU38DCAR': 'Michael Carson',
#  'PSU38DROB': 'Tania Robinson',
#  'PSU38DTAT': 'Horacena Tate (I)',
#  'PSU39DPRI': 'Linda Pritchett',
#  'PSU39DWIL': 'Nikema Williams (I)',
#  'PSU40DHAR': 'Sally Harrell (I)',
#  'PSU40RGUA': 'Garry Guan',
#  'PSU41DFRE': 'Gil Freeman',
#  'PSU41DHOS': 'Mohammed Jahangir Hossain',
#  'PSU41DJAC': 'Kim Jackson',
#  'PSU41DJON': 'Beverly R. Jones',
#  'PSU41RFRE': 'William Park Freeman',
#  'PSU42DPAR': 'Elena Parent (I)',
#  'PSU43DAND': 'Tonya P. Anderson (I)',
#  'PSU43RWIL': 'Melanie Williams',
#  'PSU44DDAV': 'Gail Davenport (I)',
#  'PSU44DJOH': 'Myah Johnson',
#  'PSU44RBRO': 'Benjamin Brooks',
#  'PSU45DANA': 'Ernie Anaya',
#  'PSU45DJON': 'Matielyn Jones',
#  'PSU45DSMI': 'Richard Smith',
#  'PSU45RBAK': 'Sammy Baker',
#  'PSU45RDIX': 'Clint Dixon',
#  'PSU45RPUN': 'Noemi Puntier',
#  'PSU46DPER': 'Zachary Perry',
#  'PSU46RCOW': 'Bill Cowsert (I)',
#  'PSU47DJOH': 'Dawn Johnson',
#  'PSU47RGIN': 'Frank Ginn (I)',
#  'PSU48DAU': 'Michelle Au',
#  'PSU48DUDD': 'Josh Uddin',
#  'PSU48RREE': 'Matt Reeves',
#  'PSU49RMIL': 'Cecil T. ""Butch"" Miller (I)',
#  'PSU50DDAL': 'Dee Daley',
#  'PSU50RGAR': 'Andy Garrison',
#  'PSU50RGAS': 'Dan Gasaway',
#  'PSU50RHAL': 'Stacy Hall',
#  'PSU50RHAT': 'Bo Hatchett',
#  'PSU50RHIS': 'Tricia Lynne Hise',
#  'PSU50RMOO': 'Lee Moore',
#  'PSU51DKRI': 'June Krise',
#  'PSU51RGOO': 'Steve Gooch (I)',
#  'PSU52DDEY': 'Charles DeYoung',
#  'PSU52RHUF': 'Chuck Hufstetler (I)',
#  'PSU53RMOO': 'Colton Moore',
#  'PSU53RMUL': 'Jeff Mullis (I)',
#  'PSU53RNOB': 'Todd Noblitt',
#  'PSU54RMCE': 'Dan L. McEntire',
#  'PSU54RPAY': 'Chuck Payne (I)',
#  'PSU55DBUT': 'Gloria S. Butler (I)',
#  'PSU56DBEE': 'Sarah Beeson',
#  'PSU56RALB': 'John Albers (I)',
#  'RCON01DGRI': 'Joyce Marie Griggs',
#  'RCON01DRIN': 'Lisa M. Ring',
#  'RCON09DPAN': 'Devin Pandy',
#  'RCON09DSIS': 'Brooke Siskin',
#  'RCON09RCLY': 'Andrew Clyde',
#  'RCON09RGUR': 'Matt Gurtler',
#  'RCON14RCOW': 'John Cowan',
#  'RCON14RGRE': 'Marjorie Taylor Greene',
#  'RSL001RCAM': 'Mike Cameron',
#  'RSL001RDEF': 'John Deffenbaugh',
#  'RSL009RLEI': 'Steve Leibel',
#  'RSL009RWAD': 'Will Wade',
#  'RSL010RAND': 'Victor E. Anderson',
#  'RSL010RCRU': 'Robert A. Crumley',
#  'RSL018RHIG': 'Cason Hightower',
#  'RSL018RSMI': 'Tyler Paul Smith',
#  'RSL020RBYR': 'Charlice Byrd',
#  'RSL020RSIN': 'Katrina Singletary',
#  'RSL021RFIN': 'Bill Fincher',
#  'RSL021RTHO': 'Brad Thomas',
#  'RSL033RLEV': 'Rob Leverett',
#  'RSL033RSTR': 'Tripp Strickland',
#  'RSL035DCAM': 'Lisa Campbell',
#  'RSL035DRIN': 'Kyle Rinaudo',
#  'RSL065DBEA': 'Sharon Beasley-Teague (I)',
#  'RSL065DTHO': 'Mandisha A. Thomas',
#  'RSL086DHEN': 'Michele Henson (I)',
#  'RSL086DLOP': 'Zulma Lopez',
#  'RSL163DMAL': 'Derek J. Mallow',
#  'RSL163DWES': 'Anne Allen Westbrook',
#  'RSU03RMCN': 'Sheila McNeill',
#  'RSU03RSHA': 'David Sharpe',
#  'RSU04RBOH': 'Scott Bohlke',
#  'RSU04RHIC': 'Billy Hickman',
#  'RSU09DMER': 'Nikki Merritt',
#  'RSU09DOKO': 'Gabe Okoye',
#  'RSU30DEDW': 'Montenia Edwards',
#  'RSU30DJAM': 'Triana Arnold James',
#  'RSU31RANA': 'Jason Anavitarte',
#  'RSU31RAUS': 'Boyd Austin',
#  'RSU50RHAL': 'Stacy Hall',
#  'RSU50RHAT': 'Bo Hatchett',
#  'SRSU04RBOH': 'Scott Bohlke',
#  'SRSU04RHIC': 'Billy Hickman',
#  'SSU04ISAM': 'Stephen Jared Sammons',
#  'SSU04RBOH': 'Scott Bohlke',
#  'SSU04RHIC': 'Billy Hickman',
#  'SSU04RPAL': 'Kathy Palmer',
#  'SSU04RSIN': 'Neil Singleton'}

# %%
fields_dict["UNIQUE_ID"] = 'Unique Precinct Identifier'
fields_dict['COUNTYFP'] = 'County FIPs Code'
fields_dict['DISTRICT'] = 'Precinct ID Combining FIPs and Identifier'
fields_dict['CTYSOSID'] = 'Precinct ID Combining FIPs and Identifier'
fields_dict['PRECINCT_I'] = 'Precinct Identifier'
fields_dict['PRECINCT_N'] = 'Precinct Name'
fields_dict['CTYNAME'] = 'County Name'
fields_dict['CTYNUMBER'] = 'County Number'
fields_dict['CTYNUMBER2'] = 'County Number'
fields_dict['FIPS2'] = 'County FIPs Code'
fields_dict['CONG_DIST'] = 'Congressional District'
fields_dict['SLDL_DIST'] = 'State House District'
fields_dict['SLDU_DIST'] = 'State Senate District'

# %%
stateabrv = "GA"
state = "Georgia"
year = "2020"
election_type = "primary / primary runoff"
additional_races = '''President, U.S. Senate, Public Service Commission, U.S. House, State House, State Senate'''
retrieval_date = "01/24/2022"
upload_date = "06/03/2022" 
vest_file_link = "https://dataverse.harvard.edu/file.xhtml?fileId=4863164&version=35.0"
raw_data_source = "Election results from the Georgia Secretary of State Elections Division (https://sos.ga.gov/index.php/Elections/current_and_past_elections_results) and precinct shapefiles from VEST's Georgia 2020 file for all counties but Bibb County, where a shapefile from their GIS office is used (https://www.arcgis.com/home/item.html?id=a7f37f9db50d4948b147144e4ac46f6b).Clayton County uses a portion of the 2018 redistricting shapefile from the Georgia General Assembly Reapportionment Office (https://www.legis.ga.gov/joint-office/reapportionment). Sources used to explain precinct shapefile changes are referenced in the Jupyer notebook on Github." 
state_erj_repo = "https://github.com/nonpartisan-redistricting-datahub/erj-ga"
office_codes = '''
PRE - President of the United States
USS - U.S. Senate
CON - U.S. House
PSC - Public Service Commission
CON## - U.S. Congress
SU##  - State Legislative Upper
SL###  - State Legislative Lower
'''
                
additional_notes = '''
~all files~

'''

# %%
full_readme = erj_readme_template(fields_dict, stateabrv, state, year, election_type, additional_races, retrieval_date, upload_date, vest_file_link, 
                        raw_data_source, state_erj_repo, office_codes, additional_notes)

# %%
export_readme("./ga_prim_20_prec/README.txt", "Georgia", "primary", full_readme)
# Out:
# Georgia primary  readme moved to folder

# %%
from zipfile import ZipFile

# more fine-grained control over ZIP files
with ZipFile("oh_gen_20_prec.zip", "w") as newzip:
    for val in os.listdir("./oh_gen_20_prec/"):
        newzip.write("./oh_gen_20_prec/"+val)

# %%
import geopandas as gp
import pandas as pd
import os
import re

# %%
level_race_name_dict = {"CONG_DIST":"CON",
    "SLDL_DIST":"SL",
    "SLDU_DIST":"SU"}

# %%
import geopandas as gp
import pandas as pd
import os
import re
level_race_name_dict = {"CONG_DIST":"CON",
    "SLDL_DIST":"SL",
    "SLDU_DIST":"SU"}
def district_assignment_errors(election_results_df, level):
    '''
    This function will check whether the votes in a precinct match the district assignment
    Note: As written, this will only work for fully numeric district assignments
    '''
    
    # This boolean is used to help clean up the print statements
    any_error = False
    # Convert from the name of the district assignment column, to how it is referred to in column names
    finding = level_race_name_dict[level]
    # Iterate over the dataframe row-by-row
    for index,row in election_results_df.iterrows():
        # Get the district assignment for that row
        district_assignment = row[level]
        # Iterate over every row column by column
        for val in row.index:
            # If the name for the type of district is in the column name and there are non-zero votes
            if finding in val and row[val] != 0 and val!= level and val not in ["SLDU_DIST","SLDL_DIST","CONG_DIST"]:
                # Grab the numbers for district assignments
                regex_string = finding+'\d*'
                # The len(finding) part is needed here as sometimes there is more than one digit to the district
                col_district = re.findall(regex_string, val)[0][len(finding):]
                # Makes sure that "CON", "SL", or "SU" wasn't found in a name (more than 5 characters into the col name)
                if (val.find(finding) < 5):
                    # If the district number in the column name doesn't equal the district name in the assignment column
                    if (col_district != district_assignment):
                        print(val.find(finding))
                        print(re.findall(regex_string, val))
                        if not(any_error):
                            print("***ERROR SPOTTED***")
                        print("District Assignment: ", district_assignment)
                        print("Value" , col_district)
                        print("Column", val)
                        print("Number of votes", row[val])
                        print(row["UNIQUE_ID"])
                        print(" ")
                        any_error = True
    return any_error
def run_validation(election_results_df):
    '''
    This code validates a handful of things in a given ERJ file:
    1) Whether the values in the "UNIQUE_ID" column are indeed unique
    2) That there is a "COUNTYFP" column
    3) That "UNIQUE_ID" and "COUNTYFP" are in the right order within the columns
    4) That the actual votes assigned in cases of districts match the stated district assignments.
        In other words, if we say a precinct is in CONG_DIST 4, does it only receive votes in CONG_DIST 4
        This function calls the "district_assignment_errors" function above to perform this check
    '''
    
    # Confirm that UNIQUE_ID column is unique
    assert(max(election_results_df["UNIQUE_ID"].value_counts(dropna=False)) == 1), "Non-unique UNIQUE_ID"
    print("CONFIRMED: UNIQUE_ID is unique")
    
    # Confirm that COUNTYFP column has been added
    assert('COUNTYFP' in list(election_results_df.columns)), "No 'COUNTYFP' column"
    print("CONFIRMED: COUNTYFP column added")
    
    #Check order of columns
    assert((list(election_results_df.columns)[0]=="UNIQUE_ID") and (list(election_results_df.columns)[1]=="COUNTYFP")), "Incorrect column placement"
    print("CONFIRMED: UNIQUE_ID and COUNTYFP columns in the right position")
    
    # Confirm that stated district assignment, matches actual district assignment
    contains_cong_assignment = "CONG_DIST" in list(election_results_df.columns) or "CON_DIST" in list(election_results_df.columns)
    if(contains_cong_assignment):
        assert(not(district_assignment_errors(election_results_df, "CONG_DIST"))), "Bad CONG_DIST assignment"
        print("CONFIRMED: Actual congressional votes match CONG_DIST assignment")
        
    contains_sldu_assignment = "SLDU_DIST" in list(election_results_df.columns)
    if(contains_sldu_assignment):
        assert(not(district_assignment_errors(election_results_df, "SLDU_DIST"))), "Bad SLDU_DIST assignment"
        print("CONFIRMED: Actual su votes match SLDU_DIST assignment")
        
    contains_sldl_assignment = "SLDL_DIST" in list(election_results_df.columns)
    if(contains_sldl_assignment):
        assert(not(district_assignment_errors(election_results_df, "SLDL_DIST"))), "Bad SLDL_DIST assignment"
        print("CONFIRMED: Actual sl votes match SLDL_DIST assignment")    
def validate_file(file_name):
    '''
    This is the function that will call the other needed functions
    
    file_name : Should be a string, something like "az_gen_20_prec"
    '''
    files = os.listdir("./"+file_name+"/")
    
    # Iterate over the files within that filepath
    for val in files:
        if ".shp" in val:
            print("Running check on:", val)
            file_load = gp.read_file("./"+file_name+"/"+val)
            run_validation(file_load)
            print("")
# Fill this in with your file name
file_name = "ga_prim_20_prec"

# Run the below to call the validation
validate_file(file_name)

# Example Call
# file_name = "az_gen_20_prec"
# validate_file(file_name)
# Out:
# Running check on: ga_prim_20_sldu_prec.shp
# CONFIRMED: UNIQUE_ID is unique
# CONFIRMED: COUNTYFP column added
# CONFIRMED: UNIQUE_ID and COUNTYFP columns in the right position
# CONFIRMED: Actual su votes match SLDU_DIST assignment
#
# Running check on: ga_prim_20_sldl_prec.shp
# CONFIRMED: UNIQUE_ID is unique
# CONFIRMED: COUNTYFP column added
# CONFIRMED: UNIQUE_ID and COUNTYFP columns in the right position
# CONFIRMED: Actual sl votes match SLDL_DIST assignment
#
# Running check on: ga_prim_20_st_prec.shp
# CONFIRMED: UNIQUE_ID is unique
# CONFIRMED: COUNTYFP column added
# CONFIRMED: UNIQUE_ID and COUNTYFP columns in the right position
#
# Running check on: ga_prim_20_cong_prec.shp
# CONFIRMED: UNIQUE_ID is unique
# CONFIRMED: COUNTYFP column added
# CONFIRMED: UNIQUE_ID and COUNTYFP columns in the right position
# CONFIRMED: Actual congressional votes match CONG_DIST assignment
